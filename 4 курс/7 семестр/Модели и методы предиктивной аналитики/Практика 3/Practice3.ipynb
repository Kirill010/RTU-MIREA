# %% [markdown]
# # **Практика 3**

# %%
import os
import re
import warnings
from collections import Counter
import requests
from bs4 import BeautifulSoup
import time

import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

warnings.filterwarnings("ignore")

# Настройка стилей для визуализации
plt.style.use('default')
sns.set_palette("husl")
colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#FFEAA7', '#DDA0DD', '#98D8C8', '#F7DC6F', '#BB8FCE', '#85C1E9']

# %%
# Загрузка данных NLTK
print("Загрузка ресурсов NLTK...")
resources = ['punkt', 'stopwords', 'wordnet', 'punkt_tab', 'averaged_perceptron_tagger']
for resource in resources:
    try:
        if resource in ['punkt', 'punkt_tab']:
            nltk.data.find(f'tokenizers/{resource}')
        else:
            nltk.data.find(f'corpora/{resource}')
    except LookupError:
        nltk.download(resource)
        print(f"Загружено: {resource}")
# Out:
# Загрузка ресурсов NLTK...
# Загружено: wordnet
# Загружено: averaged_perceptron_tagger
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
# Функция парсинга текста с веб-страницы по URL
def parse_text_from_url(url):
    try:
        if pd.isna(url) or not isinstance(url, str) or not url.startswith(('http://', 'https://')):
            return ''

        print(f"Парсинг URL: {url}...")

        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }

        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()

        soup = BeautifulSoup(response.content, 'html.parser')

        for script in soup(["script", "style", "nav", "footer", "header"]):
            script.decompose()

        text_elements = soup.find_all(['p', 'h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'article', 'div'])

        all_text = []
        for element in text_elements:
            text = element.get_text().strip()
            if text and len(text) > 20:
                all_text.append(text)

        full_text = ' '.join(all_text)
        full_text = re.sub(r'\s+', ' ', full_text).strip()

        time.sleep(1)

        return full_text if full_text else ''

    except requests.exceptions.RequestException as e:
        print(f"Ошибка запроса для {url}: {e}")
        return ''
    except Exception as e:
        print(f"Ошибка парсинга для {url}: {e}")
        return ''

# %%
# Загрузка данных
all_data = pd.read_csv('news_data.csv')
all_data
# Out:
#       source_api  category source_id                source_name  \
# 0    newsapi.org    crypto       NaN                   CoinDesk
# 1    newsapi.org    crypto       NaN              Cointelegraph
# 2    newsapi.org    sports      espn                       ESPN
# 3    newsapi.org    crypto       NaN                   CoinDesk
# 4    newsapi.org    crypto       NaN                   CoinDesk
# ..           ...       ...       ...                        ...
# 456  newsapi.org        ai       NaN                  Arxiv.org
# 457  newsapi.org    health       NaN                      WebMD
# 458  newsapi.org    health       NaN  World Health Organization
# 459  newsapi.org    travel       NaN             Travel+Leisure
# 460  newsapi.org  robotics       NaN                Robohub.org
#
#                              author  \
# 0          Siamak Masnavi, AI Boost
# 1      Cointelegraph by Vince Quill
# 2                Laurence Edmondson
# 3                      Aoyon Ashraf
# 4                    Stephen Alpher
# ..                              ...
# 456                   derekhecksher
# 457                 Alicia Gallegos
# 458  World Health Organization: WHO
# 459                    Staff Author
# 460                      Lucy Smith
#
#                                                  title  \
# 0    Ripple CLO Rejects the Narrative That Crypto I...
# 1    Stablecoins are really 'central business digit...
# 2           Verstappen wins chaotic Austin sprint race
# 3    'Great Hackers, Terrible Traders': How Exploit...
# 4    'Deploying More Capital — Steady Lads': Bitcoi...
# ..                                                 ...
# 456  Supporting Our AI Overlords: Redesigning Data ...
# 457           Weird, Wacky Side Effects of Weight Loss
# 458  Amended International Health Regulations enter...
# 459  Royal Caribbean Cancels All Stops to This Cari...
# 460  Self-supervised learning for soccer ball detec...
#
#                                            description  \
# 0    Ripple's top lawyer, Stuart Alderoty, explains...
# 1    Privately-issued stablecoins feature the same ...
# 2    Max Verstappen's championship chances received...
# 3    Six hacker wallets dumped ETH during the Oct. ...
# 4    Already losing favor with investors when bitco...
# ..                                                 ...
# 456  Large Language Model (LLM) agents, acting on t...
# 457  A family doctor and obesity specialist talks a...
# 458  <p>Today marks a milestone in global health go...
# 459  The cruise line paused all visits to Labadee a...
# 460  Presentation of the best paper award at the Ro...
#
#                                                    url  \
# 0    https://www.coindesk.com/policy/2025/10/18/rip...
# 1    https://cointelegraph.com/news/stablecoins-cen...
# 2    https://www.espn.com/f1/story/_/id/46603579/ma...
# 3    https://www.coindesk.com/markets/2025/10/18/gr...
# 4    https://www.coindesk.com/markets/2025/10/18/de...
# ..                                                 ...
# 456                   https://arxiv.org/abs/2509.00997
# 457  https://www.webmd.com/obesity/features/weird-w...
# 458  https://www.who.int/news/item/19-09-2025-amend...
# 459  https://www.travelandleisure.com/royal-caribbe...
# 460  https://robohub.org/self-supervised-learning-f...
#
#                                              image_url  \
# 0    https://cdn.sanity.io/images/s3y3vcno/producti...
# 1    https://images.cointelegraph.com/cdn-cgi/image...
# 2    https://a2.espncdn.com/combiner/i?img=%2Fphoto...
# 3    https://cdn.sanity.io/images/s3y3vcno/producti...
# 4    https://cdn.sanity.io/images/s3y3vcno/producti...
# ..                                                 ...
# 456  https://arxiv.org/static/browse/0.3.4/images/a...
# 457  https://img.lb.wbmdstatic.com/vim/live/webmd/c...
# 458  https://cdn.who.int/media/images/default-sourc...
# 459  https://s.yimg.com/ny/api/res/1.2/CHPdOzcJe.y9...
# 460  https://robohub.org/wp-content/uploads/2025/09...
#
#                   published_at  \
# 0    2025-10-18 18:05:56+00:00
# 1    2025-10-18 17:58:43+00:00
# 2    2025-10-18 17:56:10+00:00
# 3    2025-10-18 17:38:09+00:00
# 4    2025-10-18 17:00:00+00:00
# ..                         ...
# 456  2025-09-20 03:41:23+00:00
# 457  2025-09-19 23:39:10+00:00
# 458  2025-09-19 17:45:27+00:00
# 459  2025-09-19 17:12:09+00:00
# 460  2025-09-19 08:56:35+00:00
#
#                                                content  \
# 0    Cryptos latest media dust-up is missing the ev...
# 1    Investors should exercise discernment when con...
# 2    AUSTIN, Texas -- Max Verstappen's championship...
# 3    Last week's massive crypto crash didnt just hi...
# 4    Is crypto winter coming? It's already more tha...
# ..                                                 ...
# 456  arXivLabs is a framework that allows collabora...
# 457  If you're on a weight loss journey, you're pro...
# 458  Today marks a milestone in global health gover...
# 459  Royal Caribbean has extended its pause on sail...
# 460  Presentation of the best paper award at the Ro...
#
#                    collected_at
# 0    2025-10-19T21:10:32.632758
# 1    2025-10-19T21:10:32.632758
# 2    2025-10-19T21:10:11.318711
# 3    2025-10-19T21:10:32.632758
# 4    2025-10-19T21:10:32.632758
# ..                          ...
# 456  2025-10-19T21:10:28.609629
# 457  2025-10-19T21:10:15.130640
# 458  2025-10-19T21:10:15.130640
# 459  2025-10-19T21:10:40.632053
# 460  2025-10-19T21:10:51.742676
#
# [461 rows x 12 columns]

# %%
text_column = 'content' if 'content' in all_data.columns else \
             ('text' if 'text' in all_data.columns else all_data.columns[0])
print(f"Используется колонка: '{text_column}'")

all_data[text_column] = all_data[text_column].fillna('')
all_data['combined_raw'] = all_data[text_column].astype(str)
# Out:
# Используется колонка: 'content'

# %%
all_data['content']
# Out:
# 0      Cryptos latest media dust-up is missing the ev...
# 1      Investors should exercise discernment when con...
# 2      AUSTIN, Texas -- Max Verstappen's championship...
# 3      Last week's massive crypto crash didnt just hi...
# 4      Is crypto winter coming? It's already more tha...
#                              ...
# 456    arXivLabs is a framework that allows collabora...
# 457    If you're on a weight loss journey, you're pro...
# 458    Today marks a milestone in global health gover...
# 459    Royal Caribbean has extended its pause on sail...
# 460    Presentation of the best paper award at the Ro...
# Name: content, Length: 461, dtype: object

# %%
all_data['url']
# Out:
# 0      https://www.coindesk.com/policy/2025/10/18/rip...
# 1      https://cointelegraph.com/news/stablecoins-cen...
# 2      https://www.espn.com/f1/story/_/id/46603579/ma...
# 3      https://www.coindesk.com/markets/2025/10/18/gr...
# 4      https://www.coindesk.com/markets/2025/10/18/de...
#                              ...
# 456                     https://arxiv.org/abs/2509.00997
# 457    https://www.webmd.com/obesity/features/weird-w...
# 458    https://www.who.int/news/item/19-09-2025-amend...
# 459    https://www.travelandleisure.com/royal-caribbe...
# 460    https://robohub.org/self-supervised-learning-f...
# Name: url, Length: 461, dtype: object

# %%
# Парсинг текста из URL

parsed_texts = []

for index, url in enumerate(all_data['url']):
    print(f"Парсинг {index + 1}/{len(all_data)}: {url}...")
    text = parse_text_from_url(url)
    parsed_texts.append(text)

    if (index + 1) % 10 == 0:
        print(f"Прогресс: {index + 1}/{len(all_data)} завершено")

all_data = all_data.head(len(parsed_texts)).copy()
all_data['parsed_content'] = parsed_texts

successful_parses = sum(1 for text in parsed_texts if text.strip())
print(f"\nУспешно распарсено: {successful_parses}/{len(parsed_texts)} URL")
print(f"Процент успеха: {successful_parses/len(parsed_texts)*100:.1f}%")

text_column = 'parsed_content'
print(f"Используется колонка: '{text_column}'")
# Out:
# Парсинг 1/461: https://www.coindesk.com/policy/2025/10/18/ripple-clo-rejects-the-narrative-that-crypto-is-just-a-tool-for-crime-and-corruption...
# Парсинг URL: https://www.coindesk.com/policy/2025/10/18/ripple-clo-rejects-the-narrative-that-crypto-is-just-a-tool-for-crime-and-corruption...
# Ошибка запроса для https://www.coindesk.com/policy/2025/10/18/ripple-clo-rejects-the-narrative-that-crypto-is-just-a-tool-for-crime-and-corruption: 429 Client Error: Too Many Requests for url: https://www.coindesk.com/policy/2025/10/18/ripple-clo-rejects-the-narrative-that-crypto-is-just-a-tool-for-crime-and-corruption
# Парсинг 2/461: https://cointelegraph.com/news/stablecoins-central-business-digital-currencies...
# Парсинг URL: https://cointelegraph.com/news/stablecoins-central-business-digital-currencies...
# Парсинг 3/461: https://www.espn.com/f1/story/_/id/46603579/max-verstappen-wins-chaotic-us-gp-sprint-mclarens-crash-out...
# Парсинг URL: https://www.espn.com/f1/story/_/id/46603579/max-verstappen-wins-chaotic-us-gp-sprint-mclarens-crash-out...
# Парсинг 4/461: https://www.coindesk.com/markets/2025/10/18/great-hackers-terrible-traders-how-exploiters-panic-sold-and-lost-usd13m-during-market-chaos...
# Парсинг URL: https://www.coindesk.com/markets/2025/10/18/great-hackers-terrible-traders-how-exploiters-panic-sold-and-lost-usd13m-during-market-chaos...
# Ошибка запроса для https://www.coindesk.com/markets/2025/10/18/great-hackers-terrible-traders-how-exploiters-panic-sold-and-lost-usd13m-during-market-chaos: 429 Client Error: Too Many Requests for url: https://www.coindesk.com/markets/2025/10/18/great-hackers-terrible-traders-how-exploiters-panic-sold-and-lost-usd13m-during-market-chaos
# Парсинг 5/461: https://www.coindesk.com/markets/2025/10/18/deploying-more-capital-steady-lads-bitcoin-treasury-companies-struggle-to-halt-crash...
# Парсинг URL: https://www.coindesk.com/markets/2025/10/18/deploying-more-capital-steady-lads-bitcoin-treasury-companies-struggle-to-halt-crash...
# Ошибка запроса для https://www.coindesk.com/markets/2025/10/18/deploying-more-capital-steady-lads-bitcoin-treasury-companies-struggle-to-halt-crash: 429 Client Error: Too Many Requests for url: https://www.coindesk.com/markets/2025/10/18/deploying-more-capital-steady-lads-bitcoin-treasury-companies-struggle-to-halt-crash
# Парсинг 6/461: https://www.coindesk.com/markets/2025/10/18/bnb-outperforms-wide-market-on-growing-rwa-adoption-potential-coinbase-listing...
# Парсинг URL: https://www.coindesk.com/markets/2025/10/18/bnb-outperforms-wide-market-on-growing-rwa-adoption-potential-coinbase-listing...
# Ошибка запроса для https://www.coindesk.com/markets/2025/10/18/bnb-outperforms-wide-market-on-growing-rwa-adoption-potential-coinbase-listing: 429 Client Error: Too Many Requests for url: https://www.coindesk.com/markets/2025/10/18/bnb-outperforms-wide-market-on-growing-rwa-adoption-potential-coinbase-listing
# Парсинг 7/461: https://techcrunch.com/2025/10/18/too-burned-out-to-travel-this-new-app-fakes-your-summer-vacation-photos-for-you/...
# Парсинг URL: https://techcrunch.com/2025/10/18/too-burned-out-to-travel-this-new-app-fakes-your-summer-vacation-photos-for-you/...
# Парсинг 8/461: https://cointelegraph.com/news/sound-money-sound-beating-binance-bailout...
# Парсинг URL: https://cointelegraph.com/news/sound-money-sound-beating-binance-bailout...
# Парсинг 9/461: http://wwd.com/footwear-news/shoe-industry-news/shoes-for-a-cure-miami-breast-cancer-fundraiser-1238315623/...
# Парсинг URL: http://wwd.com/footwear-news/shoe-industry-news/shoes-for-a-cure-miami-breast-cancer-fundraiser-1238315623/...
# Парсинг 10/461: https://cointelegraph.com/news/bitcoin-price-lines-up-nicely-for-95k-drop-next-despite-bullish-rsi-data...
# Парсинг URL: https://cointelegraph.com/news/bitcoin-price-lines-up-nicely-for-95k-drop-next-despite-bullish-rsi-data...
# Прогресс: 10/461 завершено
# Парсинг 11/461: http://www.rollingstone.com/politics/politics-news/no-kings-playlist-anti-authoritarian-songs-protests-1235449753/...
# Парсинг URL: http://www.rollingstone.com/politics/politics-news/no-kings-playlist-anti-authoritarian-songs-protests-1235449753/...
# Парсинг 12/461: http://www.rollingstone.com/music/music-features/charley-pride-sings-brook-benton-endlessly-1235449864/...
# Парсинг URL: http://www.rollingstone.com/music/music-features/charley-pride-sings-brook-benton-endlessly-1235449864/...
# Парсинг 13/461: https://www.coindesk.com/policy/2025/10/18/state-of-crypto-how-to-square-decentralized-finance-with-regulatory-compliance...
# Парсинг URL: https://www.coindesk.com/policy/2025/10/18/state-of-crypto-how-to-square-decentralized-finance-with-regulatory-compliance...
# Ошибка запроса для https://www.coindesk.com/policy/2025/10/18/state-of-crypto-how-to-square-decentralized-finance-with-regulatory-compliance: 429 Client Error: Too Many Requests for url: https://www.coindesk.com/policy/2025/10/18/state-of-crypto-how-to-square-decentralized-finance-with-regulatory-compliance
# Парсинг 14/461: http://wwd.com/fashion-news/designer-luxury/ralph-lauren-giorgio-armani-bulgari-diwali-india-1238315625/...
# Парсинг URL: http://wwd.com/fashion-news/designer-luxury/ralph-lauren-giorgio-armani-bulgari-diwali-india-1238315625/...
# Парсинг 15/461: https://cointelegraph.com/news/l1-battleground-and-the-playing-field-isn-t-even...
# Парсинг URL: https://cointelegraph.com/news/l1-battleground-and-the-playing-field-isn-t-even...
# Парсинг 16/461: https://cointelegraph.com/news/what-if-quantum-computers-already-broke-bitcoin...
# Парсинг URL: https://cointelegraph.com/news/what-if-quantum-computers-already-broke-bitcoin...
# Парсинг 17/461: https://cointelegraph.com/news/robinhood-expands-tokenization-500-us-stocks-etfs-arbitrum...
# Парсинг URL: https://cointelegraph.com/news/robinhood-expands-tokenization-500-us-stocks-etfs-arbitrum...
# Парсинг 18/461: https://www.eurogamer.net/i-call-it-the-sisyphus-arpeggio-how-ludvig-forsell-and-hideo-kojima-worked-symbiotically-to-elevate-both-story-and-score...
# Парсинг URL: https://www.eurogamer.net/i-call-it-the-sisyphus-arpeggio-how-ludvig-forsell-and-hideo-kojima-worked-symbiotically-to-elevate-both-story-and-score...
# Парсинг 19/461: http://wwd.com/fashion-news/designer-luxury/hyeres-festival-2025-winner-lucas-emilio-brunner-1238315550/...
# Парсинг URL: http://wwd.com/fashion-news/designer-luxury/hyeres-festival-2025-winner-lucas-emilio-brunner-1238315550/...
# Парсинг 20/461: https://www.espn.com/nba/story/_/id/46626742/introducing-espn-basketball-power-index-2025-2026-predictions-23-nba-teams...
# Парсинг URL: https://www.espn.com/nba/story/_/id/46626742/introducing-espn-basketball-power-index-2025-2026-predictions-23-nba-teams...
# Прогресс: 20/461 завершено
# Парсинг 21/461: http://wwd.com/pop-culture/new-fashion-releases/seth-rogen-houseplant-pop-up-1238306308/...
# Парсинг URL: http://wwd.com/pop-culture/new-fashion-releases/seth-rogen-houseplant-pop-up-1238306308/...
# Парсинг 22/461: https://www.coindesk.com/opinion/2025/10/17/will-interest-payments-make-stablecoins-more-interesting...
# Парсинг URL: https://www.coindesk.com/opinion/2025/10/17/will-interest-payments-make-stablecoins-more-interesting...
# Ошибка запроса для https://www.coindesk.com/opinion/2025/10/17/will-interest-payments-make-stablecoins-more-interesting: 429 Client Error: Too Many Requests for url: https://www.coindesk.com/opinion/2025/10/17/will-interest-payments-make-stablecoins-more-interesting
# Парсинг 23/461: https://cointelegraph.com/news/ripple-1b-buy-back-fails-lift-price-can-xrp-still-rebound...
# Парсинг URL: https://cointelegraph.com/news/ripple-1b-buy-back-fails-lift-price-can-xrp-still-rebound...
# Парсинг 24/461: https://www.espn.com/nfl/story/_/id/46616098/2025-nfl-week-7-predictions-fantasy-sleepers-upsets-bets-stats-matchups...
# Парсинг URL: https://www.espn.com/nfl/story/_/id/46616098/2025-nfl-week-7-predictions-fantasy-sleepers-upsets-bets-stats-matchups...
# Парсинг 25/461: https://www.eurogamer.net/whatever-it-is-the-rog-xbox-ally-x-makes-me-pine-for-xboxs-distant-heyday...
# Парсинг URL: https://www.eurogamer.net/whatever-it-is-the-rog-xbox-ally-x-makes-me-pine-for-xboxs-distant-heyday...
# Парсинг 26/461: https://www.mindbodygreen.com/articles/how-2-minute-exercise-improves-health...
# Парсинг URL: https://www.mindbodygreen.com/articles/how-2-minute-exercise-improves-health...
# Парсинг 27/461: https://www.espn.com/soccer/story/_/id/46612318/is-club-world-cup-blame-chelsea-psg-injury-crisis...
# Парсинг URL: https://www.espn.com/soccer/story/_/id/46612318/is-club-world-cup-blame-chelsea-psg-injury-crisis...
# Парсинг 28/461: https://www.espn.com/soccer/story/_/id/46634062/transfer-rumors-news-bayern-aim-beat-liverpool-guehi...
# Парсинг URL: https://www.espn.com/soccer/story/_/id/46634062/transfer-rumors-news-bayern-aim-beat-liverpool-guehi...
# Парсинг 29/461: https://cointelegraph.com/news/uk-tax-authority-doubles-crypto-warning-letters-hmrc-crackdown...
# Парсинг URL: https://cointelegraph.com/news/uk-tax-authority-doubles-crypto-warning-letters-hmrc-crackdown...
# Парсинг 30/461: https://www.coindesk.com/markets/2025/10/18/doge-finds-support-after-tariff-led-selloff-market-awaits-next-catalyst...
# Парсинг URL: https://www.coindesk.com/markets/2025/10/18/doge-finds-support-after-tariff-led-selloff-market-awaits-next-catalyst...
# Ошибка запроса для https://www.coindesk.com/markets/2025/10/18/doge-finds-support-after-tariff-led-selloff-market-awaits-next-catalyst: 429 Client Error: Too Many Requests for url: https://www.coindesk.com/markets/2025/10/18/doge-finds-support-after-tariff-led-selloff-market-awaits-next-catalyst
# Прогресс: 30/461 завершено
# Парсинг 31/461: https://www.coindesk.com/markets/2025/10/18/xrp-stabilizes-after-early-dip-traders-eye-usd2-40-breakout...
# Парсинг URL: https://www.coindesk.com/markets/2025/10/18/xrp-stabilizes-after-early-dip-traders-eye-usd2-40-breakout...
# Ошибка запроса для https://www.coindesk.com/markets/2025/10/18/xrp-stabilizes-after-early-dip-traders-eye-usd2-40-breakout: 429 Client Error: Too Many Requests for url: https://www.coindesk.com/markets/2025/10/18/xrp-stabilizes-after-early-dip-traders-eye-usd2-40-breakout
# Парсинг 32/461: https://cointelegraph.com/news/bitcoin-etfs-shed-1-2b-in-red-week-but-schwab-remains-bullish...
# Парсинг URL: https://cointelegraph.com/news/bitcoin-etfs-shed-1-2b-in-red-week-but-schwab-remains-bullish...
# Парсинг 33/461: https://www.bloomberg.com/news/articles/2025-10-17/bessent-says-will-meet-china-s-he-in-malaysia-likely-next-week-mgv5w9hl...
# Парсинг URL: https://www.bloomberg.com/news/articles/2025-10-17/bessent-says-will-meet-china-s-he-in-malaysia-likely-next-week-mgv5w9hl...
# Ошибка запроса для https://www.bloomberg.com/news/articles/2025-10-17/bessent-says-will-meet-china-s-he-in-malaysia-likely-next-week-mgv5w9hl: 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-10-17/bessent-says-will-meet-china-s-he-in-malaysia-likely-next-week-mgv5w9hl
# Парсинг 34/461: https://cointelegraph.com/news/bitcoin-coinbase-premium-weakens-but-rsi-mirrors-april-bottom-zone...
# Парсинг URL: https://cointelegraph.com/news/bitcoin-coinbase-premium-weakens-but-rsi-mirrors-april-bottom-zone...
# Парсинг 35/461: https://www.ign.com/articles/the-biggest-pokmon-card-crashers-and-climbers-this-week-october-17...
# Парсинг URL: https://www.ign.com/articles/the-biggest-pokmon-card-crashers-and-climbers-this-week-october-17...
# Парсинг 36/461: https://variety.com/2025/film/reviews/truth-and-treason-review-1236555435/...
# Парсинг URL: https://variety.com/2025/film/reviews/truth-and-treason-review-1236555435/...
# Парсинг 37/461: http://www.rollingstone.com/music/music-news/renee-rapp-sza-good-days-cover-1235449870/...
# Парсинг URL: http://www.rollingstone.com/music/music-news/renee-rapp-sza-good-days-cover-1235449870/...
# Парсинг 38/461: https://www.espn.com/mlb/story/_/id/46630870/blue-jays-george-springer-exits-alcs-game-5-mariners-knee-hit-pitch...
# Парсинг URL: https://www.espn.com/mlb/story/_/id/46630870/blue-jays-george-springer-exits-alcs-game-5-mariners-knee-hit-pitch...
# Парсинг 39/461: http://www.rollingstone.com/music/music-news/taylor-swift-donates-100k-fan-battling-cancer-1235449908/...
# Парсинг URL: http://www.rollingstone.com/music/music-news/taylor-swift-donates-100k-fan-battling-cancer-1235449908/...
# Парсинг 40/461: http://www.billboard.com/pro/new-blackpink-album-yg-entertainment-stock-drops-label/...
# Парсинг URL: http://www.billboard.com/pro/new-blackpink-album-yg-entertainment-stock-drops-label/...
# Прогресс: 40/461 завершено
# Парсинг 41/461: https://variety.com/2025/tv/news/daytime-emmys-2025-full-winners-list-1236555619/...
# Парсинг URL: https://variety.com/2025/tv/news/daytime-emmys-2025-full-winners-list-1236555619/...
# Парсинг 42/461: https://www.espn.com/soccer/story/_/id/46629798/man-city-pep-guardiola-jack-grealish-everton-return...
# Парсинг URL: https://www.espn.com/soccer/story/_/id/46629798/man-city-pep-guardiola-jack-grealish-everton-return...
# Парсинг 43/461: https://cointelegraph.com/news/tempo-stripe-blockchain-5b-valuation-funding-round...
# Парсинг URL: https://cointelegraph.com/news/tempo-stripe-blockchain-5b-valuation-funding-round...
# Парсинг 44/461: http://www.hollywoodreporter.com/lifestyle/style/ateez-san-dolce-gabbana-global-ambassador-1236404185/...
# Парсинг URL: http://www.hollywoodreporter.com/lifestyle/style/ateez-san-dolce-gabbana-global-ambassador-1236404185/...
# Парсинг 45/461: http://wwd.com/fashion-news/fashion-scoops/mango-founders-family-says-son-innocent-1238315266/...
# Парсинг URL: http://wwd.com/fashion-news/fashion-scoops/mango-founders-family-says-son-innocent-1238315266/...
# Парсинг 46/461: https://www.espn.com/f1/story/_/id/46629720/mclarens-zak-brown-lando-norris-repercussions-small...
# Парсинг URL: https://www.espn.com/f1/story/_/id/46629720/mclarens-zak-brown-lando-norris-repercussions-small...
# Парсинг 47/461: https://cointelegraph.com/news/huobi-founder-raising-funds-ether-strategy...
# Парсинг URL: https://cointelegraph.com/news/huobi-founder-raising-funds-ether-strategy...
# Парсинг 48/461: https://austin.eater.com/restaurant-news/117139/a-plant-and-wine-bar-meant-to-feel-like-an-exhale-is-coming-to-north-loop...
# Парсинг URL: https://austin.eater.com/restaurant-news/117139/a-plant-and-wine-bar-meant-to-feel-like-an-exhale-is-coming-to-north-loop...
# Парсинг 49/461: https://www.spin.com/2025/10/snapped-sonic-alchemist-rezzs-second-edition-of-portal-a-photo-essay/...
# Парсинг URL: https://www.spin.com/2025/10/snapped-sonic-alchemist-rezzs-second-edition-of-portal-a-photo-essay/...
# Парсинг 50/461: https://cointelegraph.com/news/ethereum-foundation-veteran-dankrad-feist-join-tempo...
# Парсинг URL: https://cointelegraph.com/news/ethereum-foundation-veteran-dankrad-feist-join-tempo...
# Прогресс: 50/461 завершено
# Парсинг 51/461: http://wwd.com/menswear-news/mens-retail-business/new-york-knicks-karl-anthony-towns-fashion-games-1238314620/...
# Парсинг URL: http://wwd.com/menswear-news/mens-retail-business/new-york-knicks-karl-anthony-towns-fashion-games-1238314620/...
# Парсинг 52/461: http://www.hollywoodreporter.com/movies/movie-news/walton-goggins-joins-amber-midthunder-james-cameron-1236404144/...
# Парсинг URL: http://www.hollywoodreporter.com/movies/movie-news/walton-goggins-joins-amber-midthunder-james-cameron-1236404144/...
# Парсинг 53/461: http://www.hollywoodreporter.com/tv/tv-news/watch-be-my-guest-with-ina-garten-stream-online-free-1236404216/...
# Парсинг URL: http://www.hollywoodreporter.com/tv/tv-news/watch-be-my-guest-with-ina-garten-stream-online-free-1236404216/...
# Парсинг 54/461: https://variety.com/2025/tv/news/netflix-boots-pentagon-woke-garbage-gay-military-drama-1236555800/...
# Парсинг URL: https://variety.com/2025/tv/news/netflix-boots-pentagon-woke-garbage-gay-military-drama-1236555800/...
# Парсинг 55/461: https://cointelegraph.com/news/public-companies-hold-dollar110b-btc-but-which-are-profiting-from-the-bitcoin-standard...
# Парсинг URL: https://cointelegraph.com/news/public-companies-hold-dollar110b-btc-but-which-are-profiting-from-the-bitcoin-standard...
# Парсинг 56/461: http://www.billboard.com/pro/bts-comeback-how-much-money-k-pop-boy-band-new-music-make/...
# Парсинг URL: http://www.billboard.com/pro/bts-comeback-how-much-money-k-pop-boy-band-new-music-make/...
# Парсинг 57/461: http://wwd.com/fashion-news/designer-luxury/altagammas-luxury-ai-and-tariffs-italy-1238315101/...
# Парсинг URL: http://wwd.com/fashion-news/designer-luxury/altagammas-luxury-ai-and-tariffs-italy-1238315101/...
# Парсинг 58/461: http://wwd.com/fashion-news/fashion-scoops/la-doublej-dallas-store-opening-interview-1238314968/...
# Парсинг URL: http://wwd.com/fashion-news/fashion-scoops/la-doublej-dallas-store-opening-interview-1238314968/...
# Парсинг 59/461: https://www.ign.com/articles/apple-iphone-17-review...
# Парсинг URL: https://www.ign.com/articles/apple-iphone-17-review...
# Парсинг 60/461: https://www.espn.com/soccer/story/_/id/46628651/laliga-players-protest-barcelona-villarreal-miami-usa...
# Парсинг URL: https://www.espn.com/soccer/story/_/id/46628651/laliga-players-protest-barcelona-villarreal-miami-usa...
# Прогресс: 60/461 завершено
# Парсинг 61/461: https://techcrunch.com/2025/10/17/your-ai-tools-run-on-fracked-gas-and-bulldozed-texas-land/...
# Парсинг URL: https://techcrunch.com/2025/10/17/your-ai-tools-run-on-fracked-gas-and-bulldozed-texas-land/...
# Парсинг 62/461: http://wwd.com/fashion-news/fashion-scoops/new-york-mens-day-applications-fall-26-1238314727/...
# Парсинг URL: http://wwd.com/fashion-news/fashion-scoops/new-york-mens-day-applications-fall-26-1238314727/...
# Парсинг 63/461: http://www.rollingstone.com/music/music-latin/los-bukis-farewell-tour-reunion-cerrando-un-ciclo-1235448729/...
# Парсинг URL: http://www.rollingstone.com/music/music-latin/los-bukis-farewell-tour-reunion-cerrando-un-ciclo-1235448729/...
# Парсинг 64/461: http://www.hollywoodreporter.com/tv/tv-news/pentagon-criticism-netflix-boots-1236403902/...
# Парсинг URL: http://www.hollywoodreporter.com/tv/tv-news/pentagon-criticism-netflix-boots-1236403902/...
# Парсинг 65/461: https://www.ign.com/articles/lenovo-legion-pro-5-rtx-5070-ti-gaming-laptop-with-oled-display-drops-to-1700...
# Парсинг URL: https://www.ign.com/articles/lenovo-legion-pro-5-rtx-5070-ti-gaming-laptop-with-oled-display-drops-to-1700...
# Парсинг 66/461: http://wwd.com/fashion-news/designer-luxury/roundup-shanghai-four-shine-brightest-amid-market-slowdown-1238303197/...
# Парсинг URL: http://wwd.com/fashion-news/designer-luxury/roundup-shanghai-four-shine-brightest-amid-market-slowdown-1238303197/...
# Парсинг 67/461: https://cointelegraph.com/news/bitmex-raising-private-equity-fund-crypto-investments...
# Парсинг URL: https://cointelegraph.com/news/bitmex-raising-private-equity-fund-crypto-investments...
# Парсинг 68/461: https://variety.com/2025/gaming/news/xbox-ally-handheld-release-president-sarah-bond-interview-1236555575/...
# Парсинг URL: https://variety.com/2025/gaming/news/xbox-ally-handheld-release-president-sarah-bond-interview-1236555575/...
# Парсинг 69/461: https://www.ign.com/articles/how-to-sign-in-to-your-gaming-accounts-on-the-asus-rog-xbox-ally-x...
# Парсинг URL: https://www.ign.com/articles/how-to-sign-in-to-your-gaming-accounts-on-the-asus-rog-xbox-ally-x...
# Парсинг 70/461: http://wwd.com/pop-culture/celebrity-news/jennifer-lawrence-die-my-love-makeup-1238314705/...
# Парсинг URL: http://wwd.com/pop-culture/celebrity-news/jennifer-lawrence-die-my-love-makeup-1238314705/...
# Прогресс: 70/461 завершено
# Парсинг 71/461: https://www.ign.com/articles/atari-announces-the-intellivision-sprint-begins-reanimating-old-rivals...
# Парсинг URL: https://www.ign.com/articles/atari-announces-the-intellivision-sprint-begins-reanimating-old-rivals...
# Парсинг 72/461: http://wwd.com/footwear-news/shoe-industry-news/whistles-essen-the-label-footwear-collection-fall-2025-1238314669/...
# Парсинг URL: http://wwd.com/footwear-news/shoe-industry-news/whistles-essen-the-label-footwear-collection-fall-2025-1238314669/...
# Парсинг 73/461: https://cointelegraph.com/news/ondo-finance-sec-hold-off-nasdaq-tokenized-securities-plan...
# Парсинг URL: https://cointelegraph.com/news/ondo-finance-sec-hold-off-nasdaq-tokenized-securities-plan...
# Парсинг 74/461: https://www.spin.com/2025/10/songtrust-amplified-launch-celebrates-nycs-next-wave-of-artists/...
# Парсинг URL: https://www.spin.com/2025/10/songtrust-amplified-launch-celebrates-nycs-next-wave-of-artists/...
# Парсинг 75/461: http://www.rollingstone.com/music/music-news/dua-lipa-ben-gibbard-death-cab-for-cutie-cover-1235449722/...
# Парсинг URL: http://www.rollingstone.com/music/music-news/dua-lipa-ben-gibbard-death-cab-for-cutie-cover-1235449722/...
# Парсинг 76/461: https://www.espn.com/college-football/story/_/id/46628151/sources-texas-tech-dt-skyler-gill-howard-indefinitely...
# Парсинг URL: https://www.espn.com/college-football/story/_/id/46628151/sources-texas-tech-dt-skyler-gill-howard-indefinitely...
# Парсинг 77/461: https://cointelegraph.com/news/north-korea-hackers-etherhiding-exploit-google...
# Парсинг URL: https://cointelegraph.com/news/north-korea-hackers-etherhiding-exploit-google...
# Парсинг 78/461: https://cointelegraph.com/news/bitcoin-holds-105k-as-us-bank-stocks-recover-trump-truce-lifts-sentiment...
# Парсинг URL: https://cointelegraph.com/news/bitcoin-holds-105k-as-us-bank-stocks-recover-trump-truce-lifts-sentiment...
# Парсинг 79/461: https://www.ign.com/articles/lenovo-legion-tower-7-gaming-pc-deal-with-rtx-5090-graphics-card-drops-below-4k...
# Парсинг URL: https://www.ign.com/articles/lenovo-legion-tower-7-gaming-pc-deal-with-rtx-5090-graphics-card-drops-below-4k...
# Парсинг 80/461: https://pitchfork.com/news/cameron-winter-seemingly-covers-bruce-springsteen-dancing-in-the-dark-for-xbox-ad-watch/...
# Парсинг URL: https://pitchfork.com/news/cameron-winter-seemingly-covers-bruce-springsteen-dancing-in-the-dark-for-xbox-ad-watch/...
# Прогресс: 80/461 завершено
# Парсинг 81/461: http://wwd.com/footwear-news/shoe-trends/karlie-kloss-dorsay-pumps-new-york-1238314300/...
# Парсинг URL: http://wwd.com/footwear-news/shoe-trends/karlie-kloss-dorsay-pumps-new-york-1238314300/...
# Парсинг 82/461: https://cointelegraph.com/news/finance-redefined-oct-10-17-babylon-bitcoin-defi-breakthrough...
# Парсинг URL: https://cointelegraph.com/news/finance-redefined-oct-10-17-babylon-bitcoin-defi-breakthrough...
# Парсинг 83/461: https://www.coindesk.com/markets/2025/10/17/chainlink-s-link-plunges-9-as-intense-selling-overpowers-caliber-s-usd2m-accumulation...
# Парсинг URL: https://www.coindesk.com/markets/2025/10/17/chainlink-s-link-plunges-9-as-intense-selling-overpowers-caliber-s-usd2m-accumulation...
# Ошибка запроса для https://www.coindesk.com/markets/2025/10/17/chainlink-s-link-plunges-9-as-intense-selling-overpowers-caliber-s-usd2m-accumulation: 429 Client Error: Too Many Requests for url: https://www.coindesk.com/markets/2025/10/17/chainlink-s-link-plunges-9-as-intense-selling-overpowers-caliber-s-usd2m-accumulation
# Парсинг 84/461: http://www.rollingstone.com/music/music-features/tame-impala-haim-ayra-starr-rema-song-you-need-to-know-1235449608/...
# Парсинг URL: http://www.rollingstone.com/music/music-features/tame-impala-haim-ayra-starr-rema-song-you-need-to-know-1235449608/...
# Парсинг 85/461: https://variety.com/2025/film/global/kirsten-niehuus-president-german-federal-film-board-1236555631/...
# Парсинг URL: https://variety.com/2025/film/global/kirsten-niehuus-president-german-federal-film-board-1236555631/...
# Парсинг 86/461: https://videos.coindesk.com/previews/OesaGQup...
# Парсинг URL: https://videos.coindesk.com/previews/OesaGQup...
# Парсинг 87/461: https://www.ign.com/articles/get-a-cordless-rechargeable-electric-air-duster-for-your-pc-for-just-20...
# Парсинг URL: https://www.ign.com/articles/get-a-cordless-rechargeable-electric-air-duster-for-your-pc-for-just-20...
# Парсинг 88/461: https://cointelegraph.com/news/price-predictions-10-17-btc-eth-bnb-xrp-sol-doge-ada-hype-link-xlm...
# Парсинг URL: https://cointelegraph.com/news/price-predictions-10-17-btc-eth-bnb-xrp-sol-doge-ada-hype-link-xlm...
# Парсинг 89/461: https://variety.com/2025/film/news/variety-hollywood-and-horror-jason-blum-shudder-1236555013/...
# Парсинг URL: https://variety.com/2025/film/news/variety-hollywood-and-horror-jason-blum-shudder-1236555013/...
# Парсинг 90/461: https://techcrunch.com/2025/10/17/facebooks-ai-can-now-suggest-edits-to-the-photos-still-on-your-phone/...
# Парсинг URL: https://techcrunch.com/2025/10/17/facebooks-ai-can-now-suggest-edits-to-the-photos-still-on-your-phone/...
# Прогресс: 90/461 завершено
# Парсинг 91/461: https://variety.com/2025/tv/news/jiostar-2-billion-half-year-revenue-400-million-users-1236555624/...
# Парсинг URL: https://variety.com/2025/tv/news/jiostar-2-billion-half-year-revenue-400-million-users-1236555624/...
# Парсинг 92/461: http://wwd.com/pop-culture/celebrity-news/kristen-stewart-chanel-dress-london-film-festival-2025-1238314371/...
# Парсинг URL: http://wwd.com/pop-culture/celebrity-news/kristen-stewart-chanel-dress-london-film-festival-2025-1238314371/...
# Парсинг 93/461: https://variety.com/2025/film/news/reality-director-tina-satter-signs-linden-entertainment-1236555087/...
# Парсинг URL: https://variety.com/2025/film/news/reality-director-tina-satter-signs-linden-entertainment-1236555087/...
# Парсинг 94/461: https://www.ign.com/articles/the-biggest-magic-the-gathering-crashers-and-climbers-this-week-october-17...
# Парсинг URL: https://www.ign.com/articles/the-biggest-magic-the-gathering-crashers-and-climbers-this-week-october-17...
# Парсинг 95/461: http://wwd.com/footwear-news/shoe-trends/sarah-jessica-parker-uggs-tazz-clogs-new-york-1238314431/...
# Парсинг URL: http://wwd.com/footwear-news/shoe-trends/sarah-jessica-parker-uggs-tazz-clogs-new-york-1238314431/...
# Парсинг 96/461: http://wwd.com/fashion-news/fashion-scoops/revolve-los-angeles-lakers-first-nba-partnership-cardi-b-1238313883/...
# Парсинг URL: http://wwd.com/fashion-news/fashion-scoops/revolve-los-angeles-lakers-first-nba-partnership-cardi-b-1238313883/...
# Парсинг 97/461: https://www.ign.com/articles/call-of-duty-vs-battlefield-the-last-great-gaming-rivalry...
# Парсинг URL: https://www.ign.com/articles/call-of-duty-vs-battlefield-the-last-great-gaming-rivalry...
# Парсинг 98/461: https://techcrunch.com/2025/10/17/tech-layoffs-2025-list/...
# Парсинг URL: https://techcrunch.com/2025/10/17/tech-layoffs-2025-list/...
# Парсинг 99/461: https://techcrunch.com/2025/10/17/chatgpt-everything-to-know-about-the-ai-chatbot/...
# Парсинг URL: https://techcrunch.com/2025/10/17/chatgpt-everything-to-know-about-the-ai-chatbot/...
# Парсинг 100/461: http://wwd.com/footwear-news/shoe-trends/madison-beer-black-boots-new-york-city-1238314469/...
# Парсинг URL: http://wwd.com/footwear-news/shoe-trends/madison-beer-black-boots-new-york-city-1238314469/...
# Прогресс: 100/461 завершено
# Парсинг 101/461: https://variety.com/2025/film/news/becky-hammon-documentary-aces-coach-wnba-1236555007/...
# Парсинг URL: https://variety.com/2025/film/news/becky-hammon-documentary-aces-coach-wnba-1236555007/...
# Парсинг 102/461: http://wwd.com/pop-culture/celebrity-news/jessica-simpson-hair-alls-fair-premiere-1238314179/...
# Парсинг URL: http://wwd.com/pop-culture/celebrity-news/jessica-simpson-hair-alls-fair-premiere-1238314179/...
# Парсинг 103/461: http://www.rollingstone.com/music/music-album-reviews/tame-impala-deadbeat-review-1235448413/...
# Парсинг URL: http://www.rollingstone.com/music/music-album-reviews/tame-impala-deadbeat-review-1235448413/...
# Парсинг 104/461: http://www.rollingstone.com/music/music-news/tame-impala-acoustic-npr-tiny-desk-set-deadbeat-1235449522/...
# Парсинг URL: http://www.rollingstone.com/music/music-news/tame-impala-acoustic-npr-tiny-desk-set-deadbeat-1235449522/...
# Парсинг 105/461: https://variety.com/2025/film/news/weapons-hbo-max-release-date-streaming-how-to-watch-1236499090/...
# Парсинг URL: https://variety.com/2025/film/news/weapons-hbo-max-release-date-streaming-how-to-watch-1236499090/...
# Парсинг 106/461: http://www.rollingstone.com/music/music-features/todd-snider-pain-high-lonesome-and-then-some-1235449429/...
# Парсинг URL: http://www.rollingstone.com/music/music-features/todd-snider-pain-high-lonesome-and-then-some-1235449429/...
# Парсинг 107/461: https://variety.com/2025/film/news/pakistani-novel-in-the-company-of-strangers-film-adaptation-1236555524/...
# Парсинг URL: https://variety.com/2025/film/news/pakistani-novel-in-the-company-of-strangers-film-adaptation-1236555524/...
# Парсинг 108/461: http://www.billboard.com/music/music-news/txt-yeonjun-debut-solo-album-no-labels-release-date-1236091817/...
# Парсинг URL: http://www.billboard.com/music/music-news/txt-yeonjun-debut-solo-album-no-labels-release-date-1236091817/...
# Парсинг 109/461: http://www.rollingstone.com/music/music-features/ace-frehley-kiss-tribute-1235449402/...
# Парсинг URL: http://www.rollingstone.com/music/music-features/ace-frehley-kiss-tribute-1235449402/...
# Парсинг 110/461: http://wwd.com/footwear-news/shoe-trends/sofia-richie-shoes-snakeskin-heels-1238314173/...
# Парсинг URL: http://wwd.com/footwear-news/shoe-trends/sofia-richie-shoes-snakeskin-heels-1238314173/...
# Прогресс: 110/461 завершено
# Парсинг 111/461: https://www.spin.com/2025/10/ace-frehley-tributes/...
# Парсинг URL: https://www.spin.com/2025/10/ace-frehley-tributes/...
# Парсинг 112/461: https://www.espn.com/mens-college-basketball/story/_/id/46607545/records-gambling-syndicate-ncaa-basketball-suspicious-bets...
# Парсинг URL: https://www.espn.com/mens-college-basketball/story/_/id/46607545/records-gambling-syndicate-ncaa-basketball-suspicious-bets...
# Парсинг 113/461: http://www.rollingstone.com/music/music-news/haim-i-quit-deluxe-edition-three-new-songs-1235449345/...
# Парсинг URL: http://www.rollingstone.com/music/music-news/haim-i-quit-deluxe-edition-three-new-songs-1235449345/...
# Парсинг 114/461: https://www.ign.com/articles/stellar-blade-on-ps5-is-down-to-its-black-friday-price-right-now-at-amazon...
# Парсинг URL: https://www.ign.com/articles/stellar-blade-on-ps5-is-down-to-its-black-friday-price-right-now-at-amazon...
# Парсинг 115/461: https://variety.com/2025/film/news/shanghai-london-forum-uk-china-creative-collaboration-2025-1236555409/...
# Парсинг URL: https://variety.com/2025/film/news/shanghai-london-forum-uk-china-creative-collaboration-2025-1236555409/...
# Парсинг 116/461: https://www.spin.com/?p=548717...
# Парсинг URL: https://www.spin.com/?p=548717...
# Парсинг 117/461: http://wwd.com/pop-culture/celebrity-news/kim-kardashian-alls-fair-red-carpet-celebrity-style-1238314069/...
# Парсинг URL: http://wwd.com/pop-culture/celebrity-news/kim-kardashian-alls-fair-red-carpet-celebrity-style-1238314069/...
# Парсинг 118/461: http://wwd.com/business-news/retail/galeries-lafayette-mumbai-retail-india-1238314050/...
# Парсинг URL: http://wwd.com/business-news/retail/galeries-lafayette-mumbai-retail-india-1238314050/...
# Парсинг 119/461: https://www.espn.com/espn/betting/story/_/id/46617685/week-7-nfl-odds-spreads-lines-props-best-bets-sunday-football-games...
# Парсинг URL: https://www.espn.com/espn/betting/story/_/id/46617685/week-7-nfl-odds-spreads-lines-props-best-bets-sunday-football-games...
# Парсинг 120/461: https://www.espn.com/soccer/story/_/id/46617944/manchester-united-rebuild-too-big-fail-premier-league-liverpool...
# Парсинг URL: https://www.espn.com/soccer/story/_/id/46617944/manchester-united-rebuild-too-big-fail-premier-league-liverpool...
# Прогресс: 120/461 завершено
# Парсинг 121/461: http://www.rollingstone.com/music/music-live-reviews/mj-lenderman-gather-no-moss-tour-new-york-1235448503/...
# Парсинг URL: http://www.rollingstone.com/music/music-live-reviews/mj-lenderman-gather-no-moss-tour-new-york-1235448503/...
# Парсинг 122/461: https://variety.com/2025/digital/news/google-cloud-gaming-ai-stadia-jack-buser-interview-1236555448/...
# Парсинг URL: https://variety.com/2025/digital/news/google-cloud-gaming-ai-stadia-jack-buser-interview-1236555448/...
# Парсинг 123/461: https://techcrunch.com/2025/10/17/ousted-luminar-ceo-austin-russell-wants-to-buy-the-company/...
# Парсинг URL: https://techcrunch.com/2025/10/17/ousted-luminar-ceo-austin-russell-wants-to-buy-the-company/...
# Парсинг 124/461: http://www.rollingstone.com/music/music-latin/latin-music-reached-record-490-million-revenue-mid-year-2024-1235448936/...
# Парсинг URL: http://www.rollingstone.com/music/music-latin/latin-music-reached-record-490-million-revenue-mid-year-2024-1235448936/...
# Парсинг 125/461: https://pitchfork.com/news/13-new-albums-you-should-listen-to-now-tame-impala-sudan-archives/...
# Парсинг URL: https://pitchfork.com/news/13-new-albums-you-should-listen-to-now-tame-impala-sudan-archives/...
# Парсинг 126/461: https://www.spin.com/?p=505825...
# Парсинг URL: https://www.spin.com/?p=505825...
# Парсинг 127/461: http://www.rollingstone.com/music/music-country/niall-horan-thomas-rhett-old-tricks-1235449266/...
# Парсинг URL: http://www.rollingstone.com/music/music-country/niall-horan-thomas-rhett-old-tricks-1235449266/...
# Парсинг 128/461: http://wwd.com/fashion-news/fashion-features/gucci-fendi-bottega-veneta-cultural-currency-index-annex-1238314128/...
# Парсинг URL: http://wwd.com/fashion-news/fashion-features/gucci-fendi-bottega-veneta-cultural-currency-index-annex-1238314128/...
# Парсинг 129/461: https://www.espn.com/f1/story/_/id/46596025/formula-1-announces-new-apple-tv-us-broadcast-deal...
# Парсинг URL: https://www.espn.com/f1/story/_/id/46596025/formula-1-announces-new-apple-tv-us-broadcast-deal...
# Парсинг 130/461: http://www.rollingstone.com/music/music-features/gracie-abrams-cyndi-lauper-musicians-on-musicians-1235443725/...
# Парсинг URL: http://www.rollingstone.com/music/music-features/gracie-abrams-cyndi-lauper-musicians-on-musicians-1235443725/...
# Прогресс: 130/461 завершено
# Парсинг 131/461: http://www.rollingstone.com/music/music-features/tupac-biography-only-god-can-judge-me-excerpt-1235444817/...
# Парсинг URL: http://www.rollingstone.com/music/music-features/tupac-biography-only-god-can-judge-me-excerpt-1235444817/...
# Парсинг 132/461: https://techcrunch.com/2025/10/17/vlge-is-making-it-easier-to-world-build-and-shop-on-roblox/...
# Парсинг URL: https://techcrunch.com/2025/10/17/vlge-is-making-it-easier-to-world-build-and-shop-on-roblox/...
# Парсинг 133/461: https://www.espn.com/wnba/story/_/id/46607235/wnba-2025-cba-negotiations-cathy-engelbert-officiating...
# Парсинг URL: https://www.espn.com/wnba/story/_/id/46607235/wnba-2025-cba-negotiations-cathy-engelbert-officiating...
# Парсинг 134/461: https://www.espn.com/nba/story/_/id/46615461/bob-myers-leaves-espn-joins-harris-blitzer-group-president-sports...
# Парсинг URL: https://www.espn.com/nba/story/_/id/46615461/bob-myers-leaves-espn-joins-harris-blitzer-group-president-sports...
# Парсинг 135/461: https://www.espn.com/boxing/story/_/id/46615125/ranking-danny-garcia-nine-boxing-fights-barclays-center-erik-morales-shawn-porter-keith-thurman-more...
# Парсинг URL: https://www.espn.com/boxing/story/_/id/46615125/ranking-danny-garcia-nine-boxing-fights-barclays-center-erik-morales-shawn-porter-keith-thurman-more...
# Парсинг 136/461: http://www.rollingstone.com/culture/culture-features/riverside-church-basketball-ernie-lorch-abuse-lawsuit-1235446199/...
# Парсинг URL: http://www.rollingstone.com/culture/culture-features/riverside-church-basketball-ernie-lorch-abuse-lawsuit-1235446199/...
# Парсинг 137/461: https://www.espn.com/nba/story/_/id/46616698/the-latest-intel-lakers-knicks-rockets-bulls-heat-hawks...
# Парсинг URL: https://www.espn.com/nba/story/_/id/46616698/the-latest-intel-lakers-knicks-rockets-bulls-heat-hawks...
# Парсинг 138/461: https://www.espn.com/nba/story/_/id/46616480/steph-curry-steve-kerr-golden-state-warriors-coach-star-relationship...
# Парсинг URL: https://www.espn.com/nba/story/_/id/46616480/steph-curry-steve-kerr-golden-state-warriors-coach-star-relationship...
# Парсинг 139/461: http://www.rollingstone.com/music/music-news/foo-fighters-new-music-teaser-instagram-1235449237/...
# Парсинг URL: http://www.rollingstone.com/music/music-news/foo-fighters-new-music-teaser-instagram-1235449237/...
# Парсинг 140/461: https://www.espn.com/college-football/story/_/id/46614478/cal-football-berkeley-protestors-save-oaks-protest-2025...
# Парсинг URL: https://www.espn.com/college-football/story/_/id/46614478/cal-football-berkeley-protestors-save-oaks-protest-2025...
# Прогресс: 140/461 завершено
# Парсинг 141/461: https://www.mindbodygreen.com/articles/traded-corporate-for-new-path...
# Парсинг URL: https://www.mindbodygreen.com/articles/traded-corporate-for-new-path...
# Парсинг 142/461: https://www.espn.com/college-football/story/_/id/46608212/notre-dame-usc-bush-push-2005-rivalry...
# Парсинг URL: https://www.espn.com/college-football/story/_/id/46608212/notre-dame-usc-bush-push-2005-rivalry...
# Парсинг 143/461: https://techcrunch.com/2025/10/17/meta-previews-new-parental-controls-for-its-ai-experiences/...
# Парсинг URL: https://techcrunch.com/2025/10/17/meta-previews-new-parental-controls-for-its-ai-experiences/...
# Парсинг 144/461: https://www.ign.com/articles/silent-hill-2-remake-sales-hit-25-million-as-franchise-surpasses-10-million...
# Парсинг URL: https://www.ign.com/articles/silent-hill-2-remake-sales-hit-25-million-as-franchise-surpasses-10-million...
# Парсинг 145/461: https://variety.com/2025/film/global/carlotta-seijun-suzuki-doc-twist-mister-suzuki-yves-montmayeur-1236555344/...
# Парсинг URL: https://variety.com/2025/film/global/carlotta-seijun-suzuki-doc-twist-mister-suzuki-yves-montmayeur-1236555344/...
# Парсинг 146/461: https://www.spin.com/?p=518502...
# Парсинг URL: https://www.spin.com/?p=518502...
# Парсинг 147/461: https://www.ign.com/articles/marvel-rivals-first-ever-pve-mode-is-based-on-the-marvel-zombies-disney-show...
# Парсинг URL: https://www.ign.com/articles/marvel-rivals-first-ever-pve-mode-is-based-on-the-marvel-zombies-disney-show...
# Парсинг 148/461: https://variety.com/2025/tv/global/view-conference-claynosaurz-creator-led-transmedia-1236555313/...
# Парсинг URL: https://variety.com/2025/tv/global/view-conference-claynosaurz-creator-led-transmedia-1236555313/...
# Парсинг 149/461: https://www.espn.com/soccer/story/_/id/46615610/artetas-arsenal-striking-parallels-southgates-england...
# Парсинг URL: https://www.espn.com/soccer/story/_/id/46615610/artetas-arsenal-striking-parallels-southgates-england...
# Парсинг 150/461: https://grist.org/international/from-genocide-to-ecocide-after-years-of-war-gaza-faces-an-environmental-crisis-above-imagination/...
# Парсинг URL: https://grist.org/international/from-genocide-to-ecocide-after-years-of-war-gaza-faces-an-environmental-crisis-above-imagination/...
# Прогресс: 150/461 завершено
# Парсинг 151/461: https://variety.com/2025/film/news/shah-rukh-khan-birthday-film-festival-pvr-inox-1236555293/...
# Парсинг URL: https://variety.com/2025/film/news/shah-rukh-khan-birthday-film-festival-pvr-inox-1236555293/...
# Парсинг 152/461: https://variety.com/2025/film/global/sharjah-media-city-shams-siff-uae-1236555265/...
# Парсинг URL: https://variety.com/2025/film/global/sharjah-media-city-shams-siff-uae-1236555265/...
# Парсинг 153/461: http://wwd.com/menswear-news/mens-designer-luxury/hermes-veronique-nichanian-final-collection-successor-1238313901/...
# Парсинг URL: http://wwd.com/menswear-news/mens-designer-luxury/hermes-veronique-nichanian-final-collection-successor-1238313901/...
# Парсинг 154/461: https://www.bloomberg.com/news/articles/2025-10-15/stock-market-today-dow-s-p-live-updates...
# Парсинг URL: https://www.bloomberg.com/news/articles/2025-10-15/stock-market-today-dow-s-p-live-updates...
# Ошибка запроса для https://www.bloomberg.com/news/articles/2025-10-15/stock-market-today-dow-s-p-live-updates: 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-10-15/stock-market-today-dow-s-p-live-updates
# Парсинг 155/461: https://www.bloomberg.com/news/articles/2025-10-17/jpmorgan-in-talks-to-rent-hk-office-in-biggest-lease-sing-tao...
# Парсинг URL: https://www.bloomberg.com/news/articles/2025-10-17/jpmorgan-in-talks-to-rent-hk-office-in-biggest-lease-sing-tao...
# Ошибка запроса для https://www.bloomberg.com/news/articles/2025-10-17/jpmorgan-in-talks-to-rent-hk-office-in-biggest-lease-sing-tao: 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-10-17/jpmorgan-in-talks-to-rent-hk-office-in-biggest-lease-sing-tao
# Парсинг 156/461: http://wwd.com/fashion-news/fashion-features/cabana-open-first-seasonal-store-london-sloane-street-1238305974/...
# Парсинг URL: http://wwd.com/fashion-news/fashion-features/cabana-open-first-seasonal-store-london-sloane-street-1238305974/...
# Парсинг 157/461: http://wwd.com/beauty-industry-news/fragrance/colman-domingo-valentino-global-brand-ambassador-fragrance-1238305754/...
# Парсинг URL: http://wwd.com/beauty-industry-news/fragrance/colman-domingo-valentino-global-brand-ambassador-fragrance-1238305754/...
# Парсинг 158/461: http://wwd.com/business-news/retail/michael-kors-reopens-rockefeller-center-flagship-new-design-1238302932/...
# Парсинг URL: http://wwd.com/business-news/retail/michael-kors-reopens-rockefeller-center-flagship-new-design-1238302932/...
# Парсинг 159/461: http://wwd.com/business-news/retail/bergdorf-goodman-and-loro-piana-celebrate-the-partnership-1238301475/...
# Парсинг URL: http://wwd.com/business-news/retail/bergdorf-goodman-and-loro-piana-celebrate-the-partnership-1238301475/...
# Парсинг 160/461: http://wwd.com/fashion-news/fashion-scoops/aussie-brand-one-teaspoon-limited-edition-capsule-25-years-1238300879/...
# Парсинг URL: http://wwd.com/fashion-news/fashion-scoops/aussie-brand-one-teaspoon-limited-edition-capsule-25-years-1238300879/...
# Прогресс: 160/461 завершено
# Парсинг 161/461: https://techcrunch.com/2025/10/16/openai-pauses-sora-video-generations-of-martin-luther-king-jr/...
# Парсинг URL: https://techcrunch.com/2025/10/16/openai-pauses-sora-video-generations-of-martin-luther-king-jr/...
# Парсинг 162/461: https://variety.com/2025/film/reviews/stiller-and-meara-nothing-is-lost-review-ben-stiller-1236553610/...
# Парсинг URL: https://variety.com/2025/film/reviews/stiller-and-meara-nothing-is-lost-review-ben-stiller-1236553610/...
# Парсинг 163/461: https://www.ign.com/articles/dead-space-creator-glen-schofield-thinks-the-games-industry-is-broken-beaten-and-battered...
# Парсинг URL: https://www.ign.com/articles/dead-space-creator-glen-schofield-thinks-the-games-industry-is-broken-beaten-and-battered...
# Парсинг 164/461: https://www.espn.com/college-sports/story/_/id/46620086/proposed-big-ten-private-capital-deal-holding-pattern...
# Парсинг URL: https://www.espn.com/college-sports/story/_/id/46620086/proposed-big-ten-private-capital-deal-holding-pattern...
# Парсинг 165/461: https://www.ign.com/articles/t-mobile-apple-iphone-17-deals...
# Парсинг URL: https://www.ign.com/articles/t-mobile-apple-iphone-17-deals...
# Парсинг 166/461: https://www.nature.com/articles/d41586-025-03255-6...
# Парсинг URL: https://www.nature.com/articles/d41586-025-03255-6...
# Парсинг 167/461: https://www.nature.com/articles/s41467-025-65021-6...
# Парсинг URL: https://www.nature.com/articles/s41467-025-65021-6...
# Парсинг 168/461: https://www.nature.com/articles/s41586-025-09701-9...
# Парсинг URL: https://www.nature.com/articles/s41586-025-09701-9...
# Парсинг 169/461: https://www.nature.com/articles/d41586-025-03394-w...
# Парсинг URL: https://www.nature.com/articles/d41586-025-03394-w...
# Парсинг 170/461: https://www.nature.com/articles/s41598-025-22872-9...
# Парсинг URL: https://www.nature.com/articles/s41598-025-22872-9...
# Прогресс: 170/461 завершено
# Парсинг 171/461: https://www.nature.com/articles/s41467-025-64231-2...
# Парсинг URL: https://www.nature.com/articles/s41467-025-64231-2...
# Парсинг 172/461: https://www.nature.com/articles/s41565-025-02021-z...
# Парсинг URL: https://www.nature.com/articles/s41565-025-02021-z...
# Парсинг 173/461: https://www.nature.com/articles/s41587-025-02845-z...
# Парсинг URL: https://www.nature.com/articles/s41587-025-02845-z...
# Парсинг 174/461: https://www.nature.com/articles/d41586-025-03119-z...
# Парсинг URL: https://www.nature.com/articles/d41586-025-03119-z...
# Парсинг 175/461: https://www.nature.com/articles/s41565-025-02040-w...
# Парсинг URL: https://www.nature.com/articles/s41565-025-02040-w...
# Парсинг 176/461: https://www.nature.com/articles/s41598-025-21565-7...
# Парсинг URL: https://www.nature.com/articles/s41598-025-21565-7...
# Парсинг 177/461: https://www.ign.com/articles/ibuypower-slate-radeon-rx-9070-xt-gaming-pc-deal...
# Парсинг URL: https://www.ign.com/articles/ibuypower-slate-radeon-rx-9070-xt-gaming-pc-deal...
# Парсинг 178/461: https://www.espn.com/f1/story/_/id/46619359/lando-norris-held-accountable-mclaren-oscar-piastri-collision...
# Парсинг URL: https://www.espn.com/f1/story/_/id/46619359/lando-norris-held-accountable-mclaren-oscar-piastri-collision...
# Парсинг 179/461: https://www.ign.com/articles/baseus-picogo-ultra-slim-magsafe-power-bank-deal-for-apple-iphone-17-samsung-galaxy...
# Парсинг URL: https://www.ign.com/articles/baseus-picogo-ultra-slim-magsafe-power-bank-deal-for-apple-iphone-17-samsung-galaxy...
# Парсинг 180/461: https://www.espn.com/mens-college-basketball/story/_/id/46618816/bruce-pearl-joining-tnt-cbs-sports-college-basketball-analyst...
# Парсинг URL: https://www.espn.com/mens-college-basketball/story/_/id/46618816/bruce-pearl-joining-tnt-cbs-sports-college-basketball-analyst...
# Прогресс: 180/461 завершено
# Парсинг 181/461: https://variety.com/2025/tv/news/yellowstone-beth-and-rip-spinoff-dutton-ranch-cast-1236554818/...
# Парсинг URL: https://variety.com/2025/tv/news/yellowstone-beth-and-rip-spinoff-dutton-ranch-cast-1236554818/...
# Парсинг 182/461: https://dc.eater.com/coming-attractions/164277/cowbell-seafood-union-market-dc-coming-attractions...
# Парсинг URL: https://dc.eater.com/coming-attractions/164277/cowbell-seafood-union-market-dc-coming-attractions...
# Парсинг 183/461: https://variety.com/2025/biz/news/disney-renews-kristina-schake-chief-communications-officer-june-2027-1236554888/...
# Парсинг URL: https://variety.com/2025/biz/news/disney-renews-kristina-schake-chief-communications-officer-june-2027-1236554888/...
# Парсинг 184/461: http://wwd.com/business-news/human-resources/hermes-veronique-nichanian-mens-artistic-director-departure-1238306952/...
# Парсинг URL: http://wwd.com/business-news/human-resources/hermes-veronique-nichanian-mens-artistic-director-departure-1238306952/...
# Парсинг 185/461: https://www.espn.com/nba/story/_/id/46617735/bucks-aj-green-agree-4-year-45-million-extension...
# Парсинг URL: https://www.espn.com/nba/story/_/id/46617735/bucks-aj-green-agree-4-year-45-million-extension...
# Парсинг 186/461: http://wwd.com/eye/people/photographer-rodney-smiths-exhibit-book-1238306894/...
# Парсинг URL: http://wwd.com/eye/people/photographer-rodney-smiths-exhibit-book-1238306894/...
# Парсинг 187/461: https://techcrunch.com/2025/10/16/waymo-dips-its-wheels-back-into-delivery-this-time-with-doordash/...
# Парсинг URL: https://techcrunch.com/2025/10/16/waymo-dips-its-wheels-back-into-delivery-this-time-with-doordash/...
# Парсинг 188/461: https://seattle.eater.com/dining-report/89073/de-la-soil-restaurant-review-seattle-kenmore...
# Парсинг URL: https://seattle.eater.com/dining-report/89073/de-la-soil-restaurant-review-seattle-kenmore...
# Парсинг 189/461: https://techcrunch.com/2025/10/16/kayak-launches-an-ai-mode-for-travel-questions-search-and-bookings/...
# Парсинг URL: https://techcrunch.com/2025/10/16/kayak-launches-an-ai-mode-for-travel-questions-search-and-bookings/...
# Парсинг 190/461: https://variety.com/2025/film/global/warner-bros-israeli-film-boycott-violates-policy-1236554607/...
# Парсинг URL: https://variety.com/2025/film/global/warner-bros-israeli-film-boycott-violates-policy-1236554607/...
# Прогресс: 190/461 завершено
# Парсинг 191/461: https://techcrunch.com/2025/10/16/amazons-ring-to-partner-with-flock-a-network-of-ai-cameras-used-by-ice-feds-and-police/...
# Парсинг URL: https://techcrunch.com/2025/10/16/amazons-ring-to-partner-with-flock-a-network-of-ai-cameras-used-by-ice-feds-and-police/...
# ...
# Ошибка запроса для https://www.bloomberg.com/news/articles/2025-09-27/jaguar-land-rover-gets-uk-guarantee-for-1-5-billion-loan: 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-09-27/jaguar-land-rover-gets-uk-guarantee-for-1-5-billion-loan
# Парсинг 408/461: https://apod.nasa.gov/apod/ap250927.html...
# Парсинг URL: https://apod.nasa.gov/apod/ap250927.html...
# Парсинг 409/461: https://science.nasa.gov/learning-resources/for-professionals/courses-curriculums/from-city-lights-to-moonlight-nasa-training-shows-how-urban-parks-can-connect-communities-with-space-science/...
# Парсинг URL: https://science.nasa.gov/learning-resources/for-professionals/courses-curriculums/from-city-lights-to-moonlight-nasa-training-shows-how-urban-parks-can-connect-communities-with-space-science/...
# Парсинг 410/461: https://www.nasa.gov/news-release/nasa-awards-custodial-landscaping-services-contract/...
# Парсинг URL: https://www.nasa.gov/news-release/nasa-awards-custodial-landscaping-services-contract/...
# Прогресс: 410/461 завершено
# Парсинг 411/461: https://grist.org/accountability/philadelphia-sues-ziploc-sc-johnson-bimbo-bakeries-recycling-symbol-how2recycle/...
# Парсинг URL: https://grist.org/accountability/philadelphia-sues-ziploc-sc-johnson-bimbo-bakeries-recycling-symbol-how2recycle/...
# Парсинг 412/461: https://www.nasa.gov/blogs/spacestation/2025/09/26/crew-studies-space-orientation-dna-data-storage-as-dragon-reboosts-station/...
# Парсинг URL: https://www.nasa.gov/blogs/spacestation/2025/09/26/crew-studies-space-orientation-dna-data-storage-as-dragon-reboosts-station/...
# Парсинг 413/461: https://www.nasa.gov/directorates/stmd/prizes-challenges-crowdsourcing-program/centennial-challenges/lunar-challenge-winner-tests-technology-in-nasa-thermal-vacuum-chamber/...
# Парсинг URL: https://www.nasa.gov/directorates/stmd/prizes-challenges-crowdsourcing-program/centennial-challenges/lunar-challenge-winner-tests-technology-in-nasa-thermal-vacuum-chamber/...
# Парсинг 414/461: https://www.nasa.gov/directorates/armd/2025-dwu-hs-design-challenge/...
# Парсинг URL: https://www.nasa.gov/directorates/armd/2025-dwu-hs-design-challenge/...
# Парсинг 415/461: https://www.nasa.gov/image-article/golden-lake/...
# Парсинг URL: https://www.nasa.gov/image-article/golden-lake/...
# Парсинг 416/461: https://science.nasa.gov/solar-system/moon/join-nasa-on-oct-4-in-looking-up-celebrating-moon/...
# Парсинг URL: https://science.nasa.gov/solar-system/moon/join-nasa-on-oct-4-in-looking-up-celebrating-moon/...
# Парсинг 417/461: https://www.nasa.gov/missions/artemis/i-am-artemis/i-am-artemis-diamond-st-john/...
# Парсинг URL: https://www.nasa.gov/missions/artemis/i-am-artemis/i-am-artemis-diamond-st-john/...
# Парсинг 418/461: https://science.nasa.gov/missions/hubble/hubble-captures-puzzling-galaxy/...
# Парсинг URL: https://science.nasa.gov/missions/hubble/hubble-captures-puzzling-galaxy/...
# Парсинг 419/461: https://www.nasa.gov/blogs/spacestation/2025/09/25/space-medicine-protecting-crews-station-reboost-aborted/...
# Парсинг URL: https://www.nasa.gov/blogs/spacestation/2025/09/25/space-medicine-protecting-crews-station-reboost-aborted/...
# Парсинг 420/461: https://www.nasa.gov/centers-and-facilities/langley/nasa-flights-study-cosmic-ray-effects-for-air-future-space-travelers/...
# Парсинг URL: https://www.nasa.gov/centers-and-facilities/langley/nasa-flights-study-cosmic-ray-effects-for-air-future-space-travelers/...
# Прогресс: 420/461 завершено
# Парсинг 421/461: https://www.nasa.gov/directorates/esdmd/artemis-campaign-development-division/human-landing-system-program/human-lander-challenge/nasa-opens-2026-human-lander-challenge-for-life-support-systems-more/...
# Парсинг URL: https://www.nasa.gov/directorates/esdmd/artemis-campaign-development-division/human-landing-system-program/human-lander-challenge/nasa-opens-2026-human-lander-challenge-for-life-support-systems-more/...
# Парсинг 422/461: https://www.bloomberg.com/news/articles/2025-09-25/india-heads-for-busiest-month-for-ipos-in-nearly-three-decades...
# Парсинг URL: https://www.bloomberg.com/news/articles/2025-09-25/india-heads-for-busiest-month-for-ipos-in-nearly-three-decades...
# Ошибка запроса для https://www.bloomberg.com/news/articles/2025-09-25/india-heads-for-busiest-month-for-ipos-in-nearly-three-decades: 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-09-25/india-heads-for-busiest-month-for-ipos-in-nearly-three-decades
# Парсинг 423/461: https://robohub.org/robocup-logistics-league-an-interview-with-alexander-ferrein-till-hofmann-and-wataru-uemura/...
# Парсинг URL: https://robohub.org/robocup-logistics-league-an-interview-with-alexander-ferrein-till-hofmann-and-wataru-uemura/...
# Парсинг 424/461: https://www.bloomberg.com/news/articles/2025-09-25/china-urges-its-companies-to-avoid-taking-price-wars-to-the-us...
# Парсинг URL: https://www.bloomberg.com/news/articles/2025-09-25/china-urges-its-companies-to-avoid-taking-price-wars-to-the-us...
# Ошибка запроса для https://www.bloomberg.com/news/articles/2025-09-25/china-urges-its-companies-to-avoid-taking-price-wars-to-the-us: 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-09-25/china-urges-its-companies-to-avoid-taking-price-wars-to-the-us
# Парсинг 425/461: https://www.mindbodygreen.com/articles/is-your-skin-dehydrated-pinch-your-skin-to-find-out-same-as-dehydrated-skin...
# Парсинг URL: https://www.mindbodygreen.com/articles/is-your-skin-dehydrated-pinch-your-skin-to-find-out-same-as-dehydrated-skin...
# Парсинг 426/461: https://www.bloomberg.com/news/articles/2025-09-24/intel-is-seeking-an-investment-from-apple-as-part-of-its-comeback-bid?embedded-checkout=true...
# Парсинг URL: https://www.bloomberg.com/news/articles/2025-09-24/intel-is-seeking-an-investment-from-apple-as-part-of-its-comeback-bid?embedded-checkout=true...
# Ошибка запроса для https://www.bloomberg.com/news/articles/2025-09-24/intel-is-seeking-an-investment-from-apple-as-part-of-its-comeback-bid?embedded-checkout=true: 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-09-24/intel-is-seeking-an-investment-from-apple-as-part-of-its-comeback-bid?embedded-checkout=true
# Парсинг 427/461: https://www.bloomberg.com/news/articles/2025-09-24/hinduja-flagship-kicks-off-china-tieup-with-battery-making-goal...
# Парсинг URL: https://www.bloomberg.com/news/articles/2025-09-24/hinduja-flagship-kicks-off-china-tieup-with-battery-making-goal...
# Ошибка запроса для https://www.bloomberg.com/news/articles/2025-09-24/hinduja-flagship-kicks-off-china-tieup-with-battery-making-goal: 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-09-24/hinduja-flagship-kicks-off-china-tieup-with-battery-making-goal
# Парсинг 428/461: https://www.mindbodygreen.com/articles/heat-healer-energy-mat-review-2025...
# Парсинг URL: https://www.mindbodygreen.com/articles/heat-healer-energy-mat-review-2025...
# Парсинг 429/461: https://grist.org/climate/the-oceans-just-hit-an-ominous-milestone/...
# Парсинг URL: https://grist.org/climate/the-oceans-just-hit-an-ominous-milestone/...
# Парсинг 430/461: https://grist.org/oceans/the-oceans-just-hit-an-ominous-milestone/...
# Парсинг URL: https://grist.org/oceans/the-oceans-just-hit-an-ominous-milestone/...
# Прогресс: 430/461 завершено
# Парсинг 431/461: https://www.webmd.com/lupus/cm/lupus-caring-for-yourself...
# Парсинг URL: https://www.webmd.com/lupus/cm/lupus-caring-for-yourself...
# Парсинг 432/461: https://www.webmd.com/baby/news/20250923/pregnant-and-taking-tylenol-5-things-to-know-right-now...
# Парсинг URL: https://www.webmd.com/baby/news/20250923/pregnant-and-taking-tylenol-5-things-to-know-right-now...
# Парсинг 433/461: https://www.mindbodygreen.com/articles/human-brains-are-getting-biggerheres-what-it-means-for-health-to-memory-supplements...
# Парсинг URL: https://www.mindbodygreen.com/articles/human-brains-are-getting-biggerheres-what-it-means-for-health-to-memory-supplements...
# Парсинг 434/461: https://www.bloomberg.com/news/articles/2025-09-24/capitaland-reit-in-talks-to-trim-india-assets-to-generate-cash...
# Парсинг URL: https://www.bloomberg.com/news/articles/2025-09-24/capitaland-reit-in-talks-to-trim-india-assets-to-generate-cash...
# Ошибка запроса для https://www.bloomberg.com/news/articles/2025-09-24/capitaland-reit-in-talks-to-trim-india-assets-to-generate-cash: 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-09-24/capitaland-reit-in-talks-to-trim-india-assets-to-generate-cash
# Парсинг 435/461: https://www.mindbodygreen.com/articles/run-tested-runner-approved-3-nike-shoes-that-are-worth-hype...
# Парсинг URL: https://www.mindbodygreen.com/articles/run-tested-runner-approved-3-nike-shoes-that-are-worth-hype...
# Парсинг 436/461: https://www.mindbodygreen.com/articles/mediterranean-diet-may-lower-depression-risk-in-women-60-healthy-fats...
# Парсинг URL: https://www.mindbodygreen.com/articles/mediterranean-diet-may-lower-depression-risk-in-women-60-healthy-fats...
# Парсинг 437/461: https://www.mindbodygreen.com/articles/possible-relationship-between-mindset-and-weight-loss-make-a-difference...
# Парсинг URL: https://www.mindbodygreen.com/articles/possible-relationship-between-mindset-and-weight-loss-make-a-difference...
# Парсинг 438/461: https://www.who.int/news/item/24-09-2025-who-statement-on-autism-related-issues...
# Парсинг URL: https://www.who.int/news/item/24-09-2025-who-statement-on-autism-related-issues...
# Парсинг 439/461: https://www.bloomberg.com/news/articles/2025-09-23/rbc-s-dave-mckay-says-us-visa-fee-gives-canada-a-chance-to-grab-tech-talent...
# Парсинг URL: https://www.bloomberg.com/news/articles/2025-09-23/rbc-s-dave-mckay-says-us-visa-fee-gives-canada-a-chance-to-grab-tech-talent...
# Ошибка запроса для https://www.bloomberg.com/news/articles/2025-09-23/rbc-s-dave-mckay-says-us-visa-fee-gives-canada-a-chance-to-grab-tech-talent: 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-09-23/rbc-s-dave-mckay-says-us-visa-fee-gives-canada-a-chance-to-grab-tech-talent
# Парсинг 440/461: https://www.bloomberg.com/news/articles/2025-09-23/nvidia-s-massive-openai-deal-fuels-circular-financing-concerns...
# Парсинг URL: https://www.bloomberg.com/news/articles/2025-09-23/nvidia-s-massive-openai-deal-fuels-circular-financing-concerns...
# Ошибка запроса для https://www.bloomberg.com/news/articles/2025-09-23/nvidia-s-massive-openai-deal-fuels-circular-financing-concerns: 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-09-23/nvidia-s-massive-openai-deal-fuels-circular-financing-concerns
# Прогресс: 440/461 завершено
# Парсинг 441/461: https://www.renewableenergyworld.com/energy-business/what-are-we-not-talking-about-enough-energy-executives-spill-the-beans/...
# Парсинг URL: https://www.renewableenergyworld.com/energy-business/what-are-we-not-talking-about-enough-energy-executives-spill-the-beans/...
# Парсинг 442/461: https://www.travelandleisure.com/iphone-air-esim-for-travelers-11814473...
# Парсинг URL: https://www.travelandleisure.com/iphone-air-esim-for-travelers-11814473...
# Парсинг 443/461: https://www.who.int/news/item/23-09-2025-uncontrolled-high-blood-pressure-puts-over-a-billion-people-at-risk...
# Парсинг URL: https://www.who.int/news/item/23-09-2025-uncontrolled-high-blood-pressure-puts-over-a-billion-people-at-risk...
# Парсинг 444/461: https://ssir.org/articles/entry/future-oriented-leadership...
# Парсинг URL: https://ssir.org/articles/entry/future-oriented-leadership...
# Парсинг 445/461: https://www.bloomberg.com/news/articles/2025-09-23/rubio-calls-india-critical-to-us-as-h1-b-visas-add-to-tensions...
# Парсинг URL: https://www.bloomberg.com/news/articles/2025-09-23/rubio-calls-india-critical-to-us-as-h1-b-visas-add-to-tensions...
# Ошибка запроса для https://www.bloomberg.com/news/articles/2025-09-23/rubio-calls-india-critical-to-us-as-h1-b-visas-add-to-tensions: 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-09-23/rubio-calls-india-critical-to-us-as-h1-b-visas-add-to-tensions
# Парсинг 446/461: https://arxiv.org/abs/2509.06917...
# Парсинг URL: https://arxiv.org/abs/2509.06917...
# Парсинг 447/461: https://www.renewableenergyworld.com/energy-business/three-things-that-the-renewable-energy-industry-is-thinking-about-right-now/...
# Парсинг URL: https://www.renewableenergyworld.com/energy-business/three-things-that-the-renewable-energy-industry-is-thinking-about-right-now/...
# Парсинг 448/461: https://ssir.org/articles/entry/financial-backbones-strategic-capital-orchestration...
# Парсинг URL: https://ssir.org/articles/entry/financial-backbones-strategic-capital-orchestration...
# Парсинг 449/461: https://robohub.org/drones-and-droids-a-co-operative-strategy-game/...
# Парсинг URL: https://robohub.org/drones-and-droids-a-co-operative-strategy-game/...
# Парсинг 450/461: https://www.bloomberg.com/news/articles/2025-09-22/trump-s-visa-shock-strains-india-us-ties-clouds-trade-talks...
# Парсинг URL: https://www.bloomberg.com/news/articles/2025-09-22/trump-s-visa-shock-strains-india-us-ties-clouds-trade-talks...
# Ошибка запроса для https://www.bloomberg.com/news/articles/2025-09-22/trump-s-visa-shock-strains-india-us-ties-clouds-trade-talks: 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-09-22/trump-s-visa-shock-strains-india-us-ties-clouds-trade-talks
# Прогресс: 450/461 завершено
# Парсинг 451/461: https://www.mindbodygreen.com/articles/anthocyanins-help-hormone-reproductive-health...
# Парсинг URL: https://www.mindbodygreen.com/articles/anthocyanins-help-hormone-reproductive-health...
# Парсинг 452/461: https://www.mindbodygreen.com/articles/3-skin-care-habits-to-avoid-if-you-have-crepey-skin-help-ease-wrinkles...
# Парсинг URL: https://www.mindbodygreen.com/articles/3-skin-care-habits-to-avoid-if-you-have-crepey-skin-help-ease-wrinkles...
# Парсинг 453/461: https://arxiv.org/abs/2509.17280...
# Парсинг URL: https://arxiv.org/abs/2509.17280...
# Парсинг 454/461: https://arxiv.org/abs/2509.16859...
# Парсинг URL: https://arxiv.org/abs/2509.16859...
# Парсинг 455/461: https://www.travelandleisure.com/mount-washington-cog-railway-11811822...
# Парсинг URL: https://www.travelandleisure.com/mount-washington-cog-railway-11811822...
# Парсинг 456/461: https://www.bloomberg.com/news/articles/2025-09-18/fedex-sees-sales-growth-ahead-in-sign-of-parcel-demand-rebound...
# Парсинг URL: https://www.bloomberg.com/news/articles/2025-09-18/fedex-sees-sales-growth-ahead-in-sign-of-parcel-demand-rebound...
# Ошибка запроса для https://www.bloomberg.com/news/articles/2025-09-18/fedex-sees-sales-growth-ahead-in-sign-of-parcel-demand-rebound: 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-09-18/fedex-sees-sales-growth-ahead-in-sign-of-parcel-demand-rebound
# Парсинг 457/461: https://arxiv.org/abs/2509.00997...
# Парсинг URL: https://arxiv.org/abs/2509.00997...
# Парсинг 458/461: https://www.webmd.com/obesity/features/weird-wacky-side-effects-of-weight-loss...
# Парсинг URL: https://www.webmd.com/obesity/features/weird-wacky-side-effects-of-weight-loss...
# Парсинг 459/461: https://www.who.int/news/item/19-09-2025-amended-international-health-regulations-enter-into-force...
# Парсинг URL: https://www.who.int/news/item/19-09-2025-amended-international-health-regulations-enter-into-force...
# Парсинг 460/461: https://www.travelandleisure.com/royal-caribbean-suspends-labadee-2026-11813448...
# Парсинг URL: https://www.travelandleisure.com/royal-caribbean-suspends-labadee-2026-11813448...
# Прогресс: 460/461 завершено
# Парсинг 461/461: https://robohub.org/self-supervised-learning-for-soccer-ball-detection-and-beyond-interview-with-winners-of-the-robocup-2025-best-paper-award/...
# Парсинг URL: https://robohub.org/self-supervised-learning-for-soccer-ball-detection-and-beyond-interview-with-winners-of-the-robocup-2025-best-paper-award/...
#
# Успешно распарсено: 417/461 URL
# Процент успеха: 90.5%
# Используется колонка: 'parsed_content'

# %%
all_data[text_column] = all_data[text_column].fillna('')
all_data['combined_raw'] = all_data[text_column].astype(str)

# %%
# Инициализация инструментов NLP
try:
    stop_words = set(stopwords.words('english'))
except:
    stop_words = set()

lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

# Регулярные выражения для очистки
URL = re.compile(r'https?://\S+|www\.\S+')
HTML = re.compile(r'<[^>]+>')
MENTION_HASHTAG = re.compile(r'[@#]\w+')
EMOJI = re.compile(
    "["u"\U0001F600-\U0001F64F"
    u"\U0001F300-\U0001F5FF"
    u"\U0001F680-\U0001F6FF"
    u"\U00002600-\U000026FF"
    u"\U00002700-\U000027BF"
    "]+", flags=re.UNICODE)
ALPHANUMERIC = re.compile(r'[^0-9A-Za-z\s\-]')

# %%
# Предобработка данных

processed_texts = []
sentence_lists = []
token_lists = []
sentiment_labels = []
sentiment_scores_list = []
entity_records = []

for doc_index, raw_text in enumerate(all_data['combined_raw']):
    print(f"Обработка документа {doc_index + 1}/{len(all_data)}...")

    try:
        # 1. Очистка текста
        if pd.isna(raw_text):
            cleaned_text = ''
        else:
            text_string = str(raw_text)
            text_string = URL.sub(' ', text_string)
            text_string = HTML.sub(' ', text_string)
            text_string = EMOJI.sub(' ', text_string)
            text_string = MENTION_HASHTAG.sub(' ', text_string)
            text_string = ALPHANUMERIC.sub(' ', text_string)
            text_string = re.sub(r'\d+', ' ', text_string)
            text_string = re.sub(r'\s+', ' ', text_string).strip()
            cleaned_text = text_string

        # 2. Токенизация
        if not cleaned_text:
            sentences = []
            tokens = []
        else:
            sentences = sent_tokenize(cleaned_text, language='english')
            tokens = word_tokenize(cleaned_text, language='english')

        # 3. Нормализация
        normalized_tokens = []
        for token in tokens:
            processed_token = token.lower().strip()

            if not processed_token or processed_token in stop_words or len(processed_token) <= 2:
                continue

            processed_token = lemmatizer.lemmatize(processed_token)
            processed_token = stemmer.stem(processed_token)

            if processed_token and len(processed_token) > 1:
                normalized_tokens.append(processed_token)

        processed_text = ' '.join(normalized_tokens)

        processed_texts.append(processed_text)
        sentence_lists.append(sentences)
        token_lists.append(normalized_tokens)

        # 4. Анализ тональности
        if not raw_text or str(raw_text).strip() == '':
            sentiment_label = 'neutral'
            sentiment_score = 0.0
        else:
            text_lower = raw_text.lower()
            positive_words = ['good', 'great', 'excellent', 'amazing', 'wonderful', 'best', 'love', 'like', 'positive']
            negative_words = ['bad', 'terrible', 'awful', 'horrible', 'worst', 'hate', 'dislike', 'negative']

            positive_count = sum(1 for word in positive_words if word in text_lower)
            negative_count = sum(1 for word in negative_words if word in text_lower)

            total = positive_count + negative_count
            if total == 0:
                sentiment_label = 'neutral'
                sentiment_score = 0.0
            elif positive_count > negative_count:
                sentiment_score = positive_count / total
                sentiment_label = 'positive'
            elif negative_count > positive_count:
                sentiment_score = negative_count / total
                sentiment_label = 'negative'
            else:
                sentiment_label = 'neutral'
                sentiment_score = 0.0

        sentiment_labels.append(sentiment_label)
        sentiment_scores_list.append(sentiment_score)

        # 5. Извлечение сущностей
        entities = {'PERSON': [], 'ORG': [], 'DATE': [], 'GPE': []}

        if raw_text:
            words = str(raw_text).split()

            for word in words:
                if re.match(r'\d{1,2}[./-]\d{1,2}[./-]\d{2,4}', word) or re.match(r'\d{4}-\d{2}-\d{2}', word):
                    entities['DATE'].append(word)
                elif word.istitle() and len(word) > 2:
                    if word.lower() not in ['the', 'and', 'for', 'with']:
                        entities['ORG'].append(word)

            for key in entities:
                entities[key] = list(set(entities[key]))[:5]

        entity_records.append({
            'doc_id': doc_index,
            'persons': '; '.join(entities.get('PERSON', [])),
            'orgs': '; '.join(entities.get('ORG', [])),
            'dates': '; '.join(entities.get('DATE', [])),
            'locations': '; '.join(entities.get('GPE', []))
        })

    except Exception as error:
        print(f"Ошибка при обработке документа {doc_index}: {error}")
        processed_texts.append('')
        sentence_lists.append([])
        token_lists.append([])
        sentiment_labels.append('neutral')
        sentiment_scores_list.append(0.0)
        entity_records.append({
            'doc_id': doc_index,
            'persons': '', 'orgs': '', 'dates': '', 'locations': ''
        })

all_data['processed'] = processed_texts
all_data['sentences'] = sentence_lists
all_data['tokens'] = token_lists
all_data['sentiment'] = sentiment_labels
all_data['sentiment_score'] = sentiment_scores_list
# Out:
# Обработка документа 1/461...
# Обработка документа 2/461...
# Обработка документа 3/461...
# Обработка документа 4/461...
# Обработка документа 5/461...
# Обработка документа 6/461...
# Обработка документа 7/461...
# Обработка документа 8/461...
# Обработка документа 9/461...
# Обработка документа 10/461...
# Обработка документа 11/461...
# Обработка документа 12/461...
# Обработка документа 13/461...
# Обработка документа 14/461...
# Обработка документа 15/461...
# Обработка документа 16/461...
# Обработка документа 17/461...
# Обработка документа 18/461...
# Обработка документа 19/461...
# Обработка документа 20/461...
# Обработка документа 21/461...
# Обработка документа 22/461...
# Обработка документа 23/461...
# Обработка документа 24/461...
# Обработка документа 25/461...
# Обработка документа 26/461...
# Обработка документа 27/461...
# Обработка документа 28/461...
# Обработка документа 29/461...
# Обработка документа 30/461...
# Обработка документа 31/461...
# Обработка документа 32/461...
# Обработка документа 33/461...
# Обработка документа 34/461...
# Обработка документа 35/461...
# Обработка документа 36/461...
# Обработка документа 37/461...
# Обработка документа 38/461...
# Обработка документа 39/461...
# Обработка документа 40/461...
# Обработка документа 41/461...
# Обработка документа 42/461...
# Обработка документа 43/461...
# Обработка документа 44/461...
# Обработка документа 45/461...
# Обработка документа 46/461...
# Обработка документа 47/461...
# Обработка документа 48/461...
# Обработка документа 49/461...
# Обработка документа 50/461...
# Обработка документа 51/461...
# Обработка документа 52/461...
# Обработка документа 53/461...
# Обработка документа 54/461...
# Обработка документа 55/461...
# Обработка документа 56/461...
# Обработка документа 57/461...
# Обработка документа 58/461...
# Обработка документа 59/461...
# Обработка документа 60/461...
# Обработка документа 61/461...
# Обработка документа 62/461...
# Обработка документа 63/461...
# Обработка документа 64/461...
# Обработка документа 65/461...
# Обработка документа 66/461...
# Обработка документа 67/461...
# Обработка документа 68/461...
# Обработка документа 69/461...
# Обработка документа 70/461...
# Обработка документа 71/461...
# Обработка документа 72/461...
# Обработка документа 73/461...
# Обработка документа 74/461...
# Обработка документа 75/461...
# Обработка документа 76/461...
# Обработка документа 77/461...
# Обработка документа 78/461...
# Обработка документа 79/461...
# Обработка документа 80/461...
# Обработка документа 81/461...
# Обработка документа 82/461...
# Обработка документа 83/461...
# Обработка документа 84/461...
# Обработка документа 85/461...
# Обработка документа 86/461...
# Обработка документа 87/461...
# Обработка документа 88/461...
# Обработка документа 89/461...
# Обработка документа 90/461...
# Обработка документа 91/461...
# Обработка документа 92/461...
# Обработка документа 93/461...
# Обработка документа 94/461...
# Обработка документа 95/461...
# Обработка документа 96/461...
# Обработка документа 97/461...
# Обработка документа 98/461...
# Обработка документа 99/461...
# Обработка документа 100/461...
# Обработка документа 101/461...
# Обработка документа 102/461...
# Обработка документа 103/461...
# Обработка документа 104/461...
# Обработка документа 105/461...
# Обработка документа 106/461...
# Обработка документа 107/461...
# Обработка документа 108/461...
# Обработка документа 109/461...
# Обработка документа 110/461...
# Обработка документа 111/461...
# Обработка документа 112/461...
# Обработка документа 113/461...
# Обработка документа 114/461...
# Обработка документа 115/461...
# Обработка документа 116/461...
# Обработка документа 117/461...
# Обработка документа 118/461...
# Обработка документа 119/461...
# Обработка документа 120/461...
# Обработка документа 121/461...
# Обработка документа 122/461...
# Обработка документа 123/461...
# Обработка документа 124/461...
# Обработка документа 125/461...
# Обработка документа 126/461...
# Обработка документа 127/461...
# Обработка документа 128/461...
# Обработка документа 129/461...
# Обработка документа 130/461...
# Обработка документа 131/461...
# Обработка документа 132/461...
# Обработка документа 133/461...
# Обработка документа 134/461...
# Обработка документа 135/461...
# Обработка документа 136/461...
# Обработка документа 137/461...
# Обработка документа 138/461...
# Обработка документа 139/461...
# Обработка документа 140/461...
# Обработка документа 141/461...
# Обработка документа 142/461...
# Обработка документа 143/461...
# Обработка документа 144/461...
# Обработка документа 145/461...
# Обработка документа 146/461...
# Обработка документа 147/461...
# Обработка документа 148/461...
# Обработка документа 149/461...
# Обработка документа 150/461...
# Обработка документа 151/461...
# Обработка документа 152/461...
# Обработка документа 153/461...
# Обработка документа 154/461...
# Обработка документа 155/461...
# Обработка документа 156/461...
# Обработка документа 157/461...
# Обработка документа 158/461...
# Обработка документа 159/461...
# Обработка документа 160/461...
# Обработка документа 161/461...
# Обработка документа 162/461...
# Обработка документа 163/461...
# Обработка документа 164/461...
# Обработка документа 165/461...
# Обработка документа 166/461...
# Обработка документа 167/461...
# Обработка документа 168/461...
# Обработка документа 169/461...
# Обработка документа 170/461...
# Обработка документа 171/461...
# Обработка документа 172/461...
# Обработка документа 173/461...
# Обработка документа 174/461...
# Обработка документа 175/461...
# Обработка документа 176/461...
# Обработка документа 177/461...
# Обработка документа 178/461...
# Обработка документа 179/461...
# Обработка документа 180/461...
# Обработка документа 181/461...
# Обработка документа 182/461...
# Обработка документа 183/461...
# Обработка документа 184/461...
# Обработка документа 185/461...
# Обработка документа 186/461...
# Обработка документа 187/461...
# Обработка документа 188/461...
# Обработка документа 189/461...
# Обработка документа 190/461...
# Обработка документа 191/461...
# Обработка документа 192/461...
# Обработка документа 193/461...
# Обработка документа 194/461...
# Обработка документа 195/461...
# Обработка документа 196/461...
# Обработка документа 197/461...
# Обработка документа 198/461...
# Обработка документа 199/461...
# Обработка документа 200/461...
# Обработка документа 201/461...
# Обработка документа 202/461...
# Обработка документа 203/461...
# Обработка документа 204/461...
# Обработка документа 205/461...
# Обработка документа 206/461...
# Обработка документа 207/461...
# Обработка документа 208/461...
# Обработка документа 209/461...
# Обработка документа 210/461...
# Обработка документа 211/461...
# Обработка документа 212/461...
# Обработка документа 213/461...
# Обработка документа 214/461...
# Обработка документа 215/461...
# Обработка документа 216/461...
# Обработка документа 217/461...
# Обработка документа 218/461...
# Обработка документа 219/461...
# Обработка документа 220/461...
# Обработка документа 221/461...
# Обработка документа 222/461...
# Обработка документа 223/461...
# Обработка документа 224/461...
# Обработка документа 225/461...
# Обработка документа 226/461...
# Обработка документа 227/461...
# Обработка документа 228/461...
# Обработка документа 229/461...
# Обработка документа 230/461...
# Обработка документа 231/461...
# Обработка документа 232/461...
# Обработка документа 233/461...
# Обработка документа 234/461...
# Обработка документа 235/461...
# Обработка документа 236/461...
# Обработка документа 237/461...
# Обработка документа 238/461...
# Обработка документа 239/461...
# Обработка документа 240/461...
# Обработка документа 241/461...
# Обработка документа 242/461...
# Обработка документа 243/461...
# Обработка документа 244/461...
# Обработка документа 245/461...
# Обработка документа 246/461...
# Обработка документа 247/461...
# Обработка документа 248/461...
# Обработка документа 249/461...
# Обработка документа 250/461...
# Обработка документа 251/461...
# Обработка документа 252/461...
# Обработка документа 253/461...
# Обработка документа 254/461...
# Обработка документа 255/461...
# Обработка документа 256/461...
# Обработка документа 257/461...
# Обработка документа 258/461...
# Обработка документа 259/461...
# Обработка документа 260/461...
# Обработка документа 261/461...
# Обработка документа 262/461...
# Обработка документа 263/461...
# Обработка документа 264/461...
# Обработка документа 265/461...
# Обработка документа 266/461...
# Обработка документа 267/461...
# Обработка документа 268/461...
# Обработка документа 269/461...
# Обработка документа 270/461...
# Обработка документа 271/461...
# Обработка документа 272/461...
# Обработка документа 273/461...
# Обработка документа 274/461...
# Обработка документа 275/461...
# Обработка документа 276/461...
# Обработка документа 277/461...
# Обработка документа 278/461...
# Обработка документа 279/461...
# Обработка документа 280/461...
# Обработка документа 281/461...
# Обработка документа 282/461...
# Обработка документа 283/461...
# Обработка документа 284/461...
# Обработка документа 285/461...
# Обработка документа 286/461...
# Обработка документа 287/461...
# Обработка документа 288/461...
# Обработка документа 289/461...
# Обработка документа 290/461...
# Обработка документа 291/461...
# Обработка документа 292/461...
# Обработка документа 293/461...
# Обработка документа 294/461...
# Обработка документа 295/461...
# Обработка документа 296/461...
# Обработка документа 297/461...
# Обработка документа 298/461...
# Обработка документа 299/461...
# Обработка документа 300/461...
# Обработка документа 301/461...
# Обработка документа 302/461...
# Обработка документа 303/461...
# Обработка документа 304/461...
# Обработка документа 305/461...
# Обработка документа 306/461...
# Обработка документа 307/461...
# Обработка документа 308/461...
# Обработка документа 309/461...
# Обработка документа 310/461...
# Обработка документа 311/461...
# Обработка документа 312/461...
# Обработка документа 313/461...
# Обработка документа 314/461...
# Обработка документа 315/461...
# Обработка документа 316/461...
# Обработка документа 317/461...
# Обработка документа 318/461...
# Обработка документа 319/461...
# Обработка документа 320/461...
# Обработка документа 321/461...
# Обработка документа 322/461...
# Обработка документа 323/461...
# Обработка документа 324/461...
# Обработка документа 325/461...
# Обработка документа 326/461...
# Обработка документа 327/461...
# Обработка документа 328/461...
# Обработка документа 329/461...
# Обработка документа 330/461...
# Обработка документа 331/461...
# Обработка документа 332/461...
# Обработка документа 333/461...
# Обработка документа 334/461...
# Обработка документа 335/461...
# Обработка документа 336/461...
# Обработка документа 337/461...
# Обработка документа 338/461...
# Обработка документа 339/461...
# Обработка документа 340/461...
# Обработка документа 341/461...
# Обработка документа 342/461...
# Обработка документа 343/461...
# Обработка документа 344/461...
# Обработка документа 345/461...
# Обработка документа 346/461...
# Обработка документа 347/461...
# Обработка документа 348/461...
# Обработка документа 349/461...
# Обработка документа 350/461...
# Обработка документа 351/461...
# Обработка документа 352/461...
# Обработка документа 353/461...
# Обработка документа 354/461...
# Обработка документа 355/461...
# Обработка документа 356/461...
# Обработка документа 357/461...
# Обработка документа 358/461...
# Обработка документа 359/461...
# Обработка документа 360/461...
# Обработка документа 361/461...
# Обработка документа 362/461...
# Обработка документа 363/461...
# Обработка документа 364/461...
# Обработка документа 365/461...
# Обработка документа 366/461...
# Обработка документа 367/461...
# Обработка документа 368/461...
# Обработка документа 369/461...
# Обработка документа 370/461...
# Обработка документа 371/461...
# Обработка документа 372/461...
# Обработка документа 373/461...
# Обработка документа 374/461...
# Обработка документа 375/461...
# Обработка документа 376/461...
# Обработка документа 377/461...
# Обработка документа 378/461...
# Обработка документа 379/461...
# Обработка документа 380/461...
# Обработка документа 381/461...
# Обработка документа 382/461...
# Обработка документа 383/461...
# Обработка документа 384/461...
# Обработка документа 385/461...
# Обработка документа 386/461...
# Обработка документа 387/461...
# Обработка документа 388/461...
# Обработка документа 389/461...
# Обработка документа 390/461...
# Обработка документа 391/461...
# Обработка документа 392/461...
# Обработка документа 393/461...
# Обработка документа 394/461...
# Обработка документа 395/461...
# Обработка документа 396/461...
# Обработка документа 397/461...
# Обработка документа 398/461...
# Обработка документа 399/461...
# Обработка документа 400/461...
# Обработка документа 401/461...
# Обработка документа 402/461...
# Обработка документа 403/461...
# Обработка документа 404/461...
# Обработка документа 405/461...
# Обработка документа 406/461...
# Обработка документа 407/461...
# Обработка документа 408/461...
# Обработка документа 409/461...
# Обработка документа 410/461...
# Обработка документа 411/461...
# Обработка документа 412/461...
# Обработка документа 413/461...
# Обработка документа 414/461...
# Обработка документа 415/461...
# Обработка документа 416/461...
# Обработка документа 417/461...
# Обработка документа 418/461...
# Обработка документа 419/461...
# Обработка документа 420/461...
# Обработка документа 421/461...
# Обработка документа 422/461...
# Обработка документа 423/461...
# Обработка документа 424/461...
# Обработка документа 425/461...
# Обработка документа 426/461...
# Обработка документа 427/461...
# Обработка документа 428/461...
# Обработка документа 429/461...
# Обработка документа 430/461...
# Обработка документа 431/461...
# Обработка документа 432/461...
# Обработка документа 433/461...
# Обработка документа 434/461...
# Обработка документа 435/461...
# Обработка документа 436/461...
# Обработка документа 437/461...
# Обработка документа 438/461...
# Обработка документа 439/461...
# Обработка документа 440/461...
# Обработка документа 441/461...
# Обработка документа 442/461...
# Обработка документа 443/461...
# Обработка документа 444/461...
# Обработка документа 445/461...
# Обработка документа 446/461...
# Обработка документа 447/461...
# Обработка документа 448/461...
# Обработка документа 449/461...
# Обработка документа 450/461...
# Обработка документа 451/461...
# Обработка документа 452/461...
# Обработка документа 453/461...
# Обработка документа 454/461...
# Обработка документа 455/461...
# Обработка документа 456/461...
# Обработка документа 457/461...
# Обработка документа 458/461...
# Обработка документа 459/461...
# Обработка документа 460/461...
# Обработка документа 461/461...

# %%
all_data
# Out:
#       source_api  category source_id                source_name  \
# 0    newsapi.org    crypto       NaN                   CoinDesk
# 1    newsapi.org    crypto       NaN              Cointelegraph
# 2    newsapi.org    sports      espn                       ESPN
# 3    newsapi.org    crypto       NaN                   CoinDesk
# 4    newsapi.org    crypto       NaN                   CoinDesk
# ..           ...       ...       ...                        ...
# 456  newsapi.org        ai       NaN                  Arxiv.org
# 457  newsapi.org    health       NaN                      WebMD
# 458  newsapi.org    health       NaN  World Health Organization
# 459  newsapi.org    travel       NaN             Travel+Leisure
# 460  newsapi.org  robotics       NaN                Robohub.org
#
#                              author  \
# 0          Siamak Masnavi, AI Boost
# 1      Cointelegraph by Vince Quill
# 2                Laurence Edmondson
# 3                      Aoyon Ashraf
# 4                    Stephen Alpher
# ..                              ...
# 456                   derekhecksher
# 457                 Alicia Gallegos
# 458  World Health Organization: WHO
# 459                    Staff Author
# 460                      Lucy Smith
#
#                                                  title  \
# 0    Ripple CLO Rejects the Narrative That Crypto I...
# 1    Stablecoins are really 'central business digit...
# 2           Verstappen wins chaotic Austin sprint race
# 3    'Great Hackers, Terrible Traders': How Exploit...
# 4    'Deploying More Capital — Steady Lads': Bitcoi...
# ..                                                 ...
# 456  Supporting Our AI Overlords: Redesigning Data ...
# 457           Weird, Wacky Side Effects of Weight Loss
# 458  Amended International Health Regulations enter...
# 459  Royal Caribbean Cancels All Stops to This Cari...
# 460  Self-supervised learning for soccer ball detec...
#
#                                            description  \
# 0    Ripple's top lawyer, Stuart Alderoty, explains...
# 1    Privately-issued stablecoins feature the same ...
# 2    Max Verstappen's championship chances received...
# 3    Six hacker wallets dumped ETH during the Oct. ...
# 4    Already losing favor with investors when bitco...
# ..                                                 ...
# 456  Large Language Model (LLM) agents, acting on t...
# 457  A family doctor and obesity specialist talks a...
# 458  <p>Today marks a milestone in global health go...
# 459  The cruise line paused all visits to Labadee a...
# 460  Presentation of the best paper award at the Ro...
#
#                                                    url  \
# 0    https://www.coindesk.com/policy/2025/10/18/rip...
# 1    https://cointelegraph.com/news/stablecoins-cen...
# 2    https://www.espn.com/f1/story/_/id/46603579/ma...
# 3    https://www.coindesk.com/markets/2025/10/18/gr...
# 4    https://www.coindesk.com/markets/2025/10/18/de...
# ..                                                 ...
# 456                   https://arxiv.org/abs/2509.00997
# 457  https://www.webmd.com/obesity/features/weird-w...
# 458  https://www.who.int/news/item/19-09-2025-amend...
# 459  https://www.travelandleisure.com/royal-caribbe...
# 460  https://robohub.org/self-supervised-learning-f...
#
#                                              image_url  \
# 0    https://cdn.sanity.io/images/s3y3vcno/producti...
# 1    https://images.cointelegraph.com/cdn-cgi/image...
# 2    https://a2.espncdn.com/combiner/i?img=%2Fphoto...
# 3    https://cdn.sanity.io/images/s3y3vcno/producti...
# 4    https://cdn.sanity.io/images/s3y3vcno/producti...
# ..                                                 ...
# 456  https://arxiv.org/static/browse/0.3.4/images/a...
# 457  https://img.lb.wbmdstatic.com/vim/live/webmd/c...
# 458  https://cdn.who.int/media/images/default-sourc...
# 459  https://s.yimg.com/ny/api/res/1.2/CHPdOzcJe.y9...
# 460  https://robohub.org/wp-content/uploads/2025/09...
#
#                   published_at  ...                collected_at  \
# 0    2025-10-18 18:05:56+00:00  ...  2025-10-19T21:10:32.632758
# 1    2025-10-18 17:58:43+00:00  ...  2025-10-19T21:10:32.632758
# 2    2025-10-18 17:56:10+00:00  ...  2025-10-19T21:10:11.318711
# 3    2025-10-18 17:38:09+00:00  ...  2025-10-19T21:10:32.632758
# 4    2025-10-18 17:00:00+00:00  ...  2025-10-19T21:10:32.632758
# ..                         ...  ...                         ...
# 456  2025-09-20 03:41:23+00:00  ...  2025-10-19T21:10:28.609629
# 457  2025-09-19 23:39:10+00:00  ...  2025-10-19T21:10:15.130640
# 458  2025-09-19 17:45:27+00:00  ...  2025-10-19T21:10:15.130640
# 459  2025-09-19 17:12:09+00:00  ...  2025-10-19T21:10:40.632053
# 460  2025-09-19 08:56:35+00:00  ...  2025-10-19T21:10:51.742676
#
#                                           combined_raw  \
# 0
# 1    Vince Quill Oct 18, 2025 Stablecoins are reall...
# 2    Skip to main content Skip to navigation < > Ve...
# 3
# 4
# ..                                                 ...
# 456  Happy Open Access Week from arXiv! YOU make op...
# 457  Weight Loss & ObesityFeature StoriesWeight Los...
# 458  WHO / Inas Hamam COVID-19 testing and vaccinat...
# 459  Royal Caribbean Cancels All Stops to This Cari...
# 460  News Views Podcast Learn ↑ team about contribu...
#
#                                         parsed_content  \
# 0
# 1    Vince Quill Oct 18, 2025 Stablecoins are reall...
# 2    Skip to main content Skip to navigation < > Ve...
# 3
# 4
# ..                                                 ...
# 456  Happy Open Access Week from arXiv! YOU make op...
# 457  Weight Loss & ObesityFeature StoriesWeight Los...
# 458  WHO / Inas Hamam COVID-19 testing and vaccinat...
# 459  Royal Caribbean Cancels All Stops to This Cari...
# 460  News Views Podcast Learn ↑ team about contribu...
#
#                                              processed  \
# 0
# 1    vinc quill oct stablecoin realli central busi ...
# 2    skip main content skip navig verstappen win ch...
# 3
# 4
# ..                                                 ...
# 456  happi open access week arxiv make open access ...
# 457  weight loss obesityfeatur storiesweight loss o...
# 458  ina hamam covid- test vaccin centr bahrain cre...
# 459  royal caribbean cancel stop caribbean destin n...
# 460  news view podcast learn team contribut republi...
#
#                                              sentences  \
# 0                                                   []
# 1    [Vince Quill Oct Stablecoins are really centra...
# 2    [Skip to main content Skip to navigation Verst...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 456  [Happy Open Access Week from arXiv YOU make op...
# 457  [Weight Loss ObesityFeature StoriesWeight Loss...
# 458  [WHO Inas Hamam COVID- testing and vaccination...
# 459  [Royal Caribbean Cancels All Stops to This Car...
# 460  [News Views Podcast Learn team about contribut...
#
#                                                 tokens sentiment  \
# 0                                                   []   neutral
# 1    [vinc, quill, oct, stablecoin, realli, central...  positive
# 2    [skip, main, content, skip, navig, verstappen,...  positive
# 3                                                   []   neutral
# 4                                                   []   neutral
# ..                                                 ...       ...
# 456  [happi, open, access, week, arxiv, make, open,...  positive
# 457  [weight, loss, obesityfeatur, storiesweight, l...  positive
# 458  [ina, hamam, covid-, test, vaccin, centr, bahr...   neutral
# 459  [royal, caribbean, cancel, stop, caribbean, de...  positive
# 460  [news, view, podcast, learn, team, contribut, ...  positive
#
#     sentiment_score  predicted_category category_confidence
# 0          0.000000               other               0.000
# 1          0.666667              crypto               0.226
# 2          0.666667              sports               0.235
# 3          0.000000               other               0.000
# 4          0.000000               other               0.000
# ..              ...                 ...                 ...
# 456        1.000000             science               0.190
# 457        1.000000              health               0.240
# 458        0.000000              health               0.188
# 459        0.666667              travel               0.200
# 460        1.000000                  ai               0.146
#
# [461 rows x 21 columns]

# %%
# Частотный анализ

all_words = []
for text in processed_texts:
    if text:
        all_words.extend(text.split())

word_frequency = Counter(all_words)
top_20_words = word_frequency.most_common(20)

print("1. Топ-20 частых слов:")
for position, (word, frequency) in enumerate(top_20_words, 1):
    print(f"    {position}. {word} — {frequency} раз")
# Out:
# 1. Топ-20 частых слов:
#     1. articl — 21188 раз
#     2. new — 13736 раз
#     3. restaur — 11477 раз
#     4. like — 11266 раз
#     5. one — 10938 раз
#     6. googl — 10762 раз
#     7. use — 10559 раз
#     8. also — 9716 раз
#     9. share — 9390 раз
#     10. ago — 8770 раз
#     11. pubm — 8634 раз
#     12. time — 8576 раз
#     13. data — 8552 раз
#     14. read — 8323 раз
#     15. work — 8224 раз
#     16. year — 8181 раз
#     17. said — 8130 раз
#     18. get — 8119 раз
#     19. scholar — 7310 раз
#     20. week — 7276 раз

# %%
# Анализ тональности
print("2. Эмоциональная окраска текстов:")
sentiment_summary = all_data['sentiment'].value_counts().reset_index()
sentiment_summary.columns = ['sentiment', 'count']
for _, row in sentiment_summary.iterrows():
    print(f"    {row['sentiment']} — {row['count']} текстов")
# Out:
# 2. Эмоциональная окраска текстов:
#     positive — 356 текстов
#     neutral — 102 текстов
#     negative — 3 текстов

# %%
# Сущности
print("3. Ключевые сущности:")
entities_dataframe = pd.DataFrame(entity_records)
documents_to_show = min(3, len(entities_dataframe))

for doc_index in range(documents_to_show):
    entity_row = entities_dataframe.iloc[doc_index]
    print(f"Документ {doc_index + 1}:")

    if entity_row['persons']:
        print(f"  Люди: {entity_row['persons']}")
    if entity_row['orgs']:
        print(f"  Организации: {entity_row['orgs']}")
    if entity_row['locations']:
        print(f"  Места: {entity_row['locations']}")
    if entity_row['dates']:
        print(f"  Даты: {entity_row['dates']}")
    print()
# Out:
# 3. Ключевые сущности:
# Документ 1:
#
# Документ 2:
#   Организации: Global,; Patriot; Quill; Global; Jeremy
#
# Документ 3:
#   Организации: Lewis; Before; Sky; Ferraris; P3,

# %%
# Классификация по категориям
print("4. Классификация по категориям")

CATEGORY_KEYWORDS = {
    'sports': ['game', 'player', 'team', 'season', 'win', 'score', 'championship', 'match', 'league', 'tournament'],
    'technology': ['tech', 'software', 'digital', 'innovation', 'startup', 'computer', 'mobile', 'app', 'device'],
    'health': ['health', 'medical', 'doctor', 'hospital', 'disease', 'treatment', 'medicine', 'patient', 'care'],
    'business': ['business', 'market', 'company', 'investment', 'economic', 'profit', 'finance', 'stock', 'trade'],
    'science': ['science', 'research', 'study', 'scientist', 'discovery', 'experiment', 'theory', 'data'],
    'politics': ['politics', 'government', 'election', 'policy', 'minister', 'president', 'law', 'vote'],
    'music': ['music', 'song', 'album', 'artist', 'tour', 'concert', 'billboard', 'band', 'performance'],
    'environment': ['environment', 'climate', 'nature', 'eco', 'sustainable', 'green', 'planet', 'earth'],
    'entertainment': ['entertainment', 'movie', 'film', 'celebrity', 'hollywood', 'tv', 'show', 'actor'],
    'ai': ['ai', 'artificial', 'intelligence', 'machine', 'learning', 'neural', 'algorithm', 'model'],
    'cybersecurity': ['cybersecurity', 'security', 'hack', 'breach', 'malware', 'firewall', 'encryption'],
    'crypto': ['bitcoin', 'crypto', 'blockchain', 'token', 'defi', 'nft', 'ethereum', 'digital', 'currency'],
    'gaming': ['gaming', 'game', 'player', 'console', 'video', 'esports', 'stream', 'gamer'],
    'space': ['space', 'nasa', 'rocket', 'planet', 'orbit', 'satellite', 'universe', 'astronomy'],
    'fashion': ['fashion', 'designer', 'collection', 'runway', 'luxury', 'style', 'clothing', 'trend'],
    'travel': ['travel', 'trip', 'destination', 'hotel', 'flight', 'tourist', 'vacation', 'journey'],
    'food': ['food', 'restaurant', 'recipe', 'cooking', 'cuisine', 'dish', 'meal', 'culinary'],
    'books': ['book', 'author', 'novel', 'literature', 'publishing', 'reading', 'story', 'writer'],
    'wellness': ['wellness', 'health', 'fitness', 'yoga', 'meditation', 'mindfulness', 'selfcare'],
    'renewables': ['renewable', 'energy', 'solar', 'wind', 'green', 'sustainable', 'clean', 'power'],
    'edtech': ['edtech', 'education', 'learning', 'student', 'school', 'digital', 'online', 'course'],
    'robotics': ['robotics', 'robot', 'automation', 'ai', 'machine', 'autonomous', 'tech'],
    'philanthropy': ['philanthropy', 'charity', 'donation', 'nonprofit', 'foundation', 'give', 'support'],
    'other': []
}

predicted_categories = []
category_confidences = []

for text in all_data['combined_raw']:
    if not text or str(text).strip() == '':
        predicted_categories.append('other')
        category_confidences.append(0.0)
        continue

    text_lowercase = str(text).lower()
    category_scores = {}

    for category, keywords in CATEGORY_KEYWORDS.items():
        match_count = sum(1 for keyword in keywords if keyword.lower() in text_lowercase)
        category_scores[category] = match_count

    best_category = max(category_scores, key=category_scores.get)
    total_matches = sum(category_scores.values())

    confidence = (category_scores[best_category] / total_matches) if total_matches > 0 else 0.0

    if category_scores[best_category] == 0:
        predicted_categories.append('other')
        category_confidences.append(0.0)
    else:
        predicted_categories.append(best_category)
        category_confidences.append(round(confidence, 3))

all_data['predicted_category'] = predicted_categories
all_data['category_confidence'] = category_confidences

print("Категории текстов:")
category_counts = all_data['predicted_category'].value_counts()
for category, count in category_counts.items():
    print(f"    {category} — {count} текстов")
# Out:
# 4. Классификация по категориям
# Категории текстов:
#     sports — 60 текстов
#     other — 44 текстов
#     health — 44 текстов
#     technology — 37 текстов
#     science — 31 текстов
#     music — 30 текстов
#     fashion — 29 текстов
#     business — 26 текстов
#     entertainment — 21 текстов
#     environment — 20 текстов
#     food — 20 текстов
#     ai — 19 текстов
#     space — 13 текстов
#     gaming — 13 текстов
#     books — 13 текстов
#     crypto — 11 текстов
#     renewables — 11 текстов
#     politics — 6 текстов
#     robotics — 5 текстов
#     wellness — 4 текстов
#     travel — 3 текстов
#     edtech — 1 текстов

# %%
# 1. Визуализация топ-20 слов
words, counts = zip(*top_20_words)

plt.figure(figsize=(12, 8))

bars = plt.barh(words, counts, color=colors[:len(words)])
plt.xlabel('Частота')
plt.title('Топ-20 самых частых слов')
plt.gca().invert_yaxis()

plt.tight_layout()
plt.show()

# %%
# 2. Визуализация тональности
sentiment_counts = all_data['sentiment'].value_counts()

plt.figure(figsize=(12, 8))

sentiment_colors = {'positive': '#4ECDC4', 'negative': '#FF6B6B', 'neutral': '#45B7D1'}
colors_list = [sentiment_colors.get(sent, '#96CEB4') for sent in sentiment_counts.index]

bars = plt.bar(sentiment_counts.index, sentiment_counts.values, color=colors_list)
plt.title('Распределение тональности текстов')

for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
            f'{int(height)}', ha='center', va='bottom')


plt.tight_layout()
plt.savefig('sentiment_analysis.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# 3. Визуализация категорий
category_counts = all_data['predicted_category'].value_counts().head(10)

plt.figure(figsize=(12, 8))
bars = plt.barh(category_counts.index, category_counts.values, color=colors)
plt.xlabel('Количество текстов')
plt.title('Топ-10 категорий текстов')
plt.gca().invert_yaxis()

for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height()/2.,
            f' {int(width)}', va='center', ha='left')

plt.tight_layout()
plt.show()
