# %% [markdown]
# # Перенос обучения
#
# Нейронные сети большие и сложные. Чтобы хорошо обучить нейронную сеть нужно много времени, много релевантных данных. Скажем, сети для распознавания изображений обучаются на миллионах примеров изображений с тысячами разных классов, что требует недели и месяцы рассчетов, если, конечно, у вас нет компьютера с сотней-другой графических ускорителей.
#
# У меня нет, а у вас? Что же, нам бросить заниматься нейронными сетями?
#
# Оказывается, мы можем использовать чужие результаты, чтобы обучать, точней дообучать, нейронные сети для своих задач.
#
# Такой подход назвали **перенос обучения** (transfer learning). Раньше, пока к делу не подключились крупные компании, даже были фирмы которые продавали обученные слои нейронной сети ("слои свежие, только обученные, подходи - покупай"), но, к счастью, теперь огромное количество уже хорошо обученных нейронных сетей доступны бесплатно всем желающим.
#
# Вспомним, как работает сеть для классификации изображений с прошлого занятия. Изображение проходит несколько раз через сверточные слои, активацию, другие слои (например, dropout), а затем, через полносвязный слой (обычно с softmax), который и рассчитывает уровни уверенности для классов.
#
# Полносвязный слой это ведь обычная линейная регрессия. Значит все предыдущие слои так преобразовывали изображение, что оказалось достаточно линейной регрессии чтобы построить классификатор. Но, конечно, у нас это не получилось бы, если б мы пытались применить линейную регрессию сразу к изображению.
#
# Можно сказать, что промежуточные слои это некоторые преобразователи, а последний слой - классификатор.
#
# Но абсолютно теми же самыми рассуждениями можно придти к выводу, что классификатор это последние два слоя, а остальные - преобразователь. Или три...
#
# Если мы имеем хорошо обученную нейронную сеть, то слои преобразователя хороши, они ведь позволяют потом построить классификатор.
#
# А давайте возьмем "хороший" преобразователь от уже кем-то обученной сети (многие компании и ученые дают нам такие сети). А классификатор сделаем свой, для нашей задачи. Получится, что мы как бы отрезали последние слои у сети и заменили их на свои (рис.).
#
# И уже эту сеть, с заранее обученным преобразователем, но еще не обученным классификатором, будем обучать. Тут можно как зафиксировать и не обучать слои от преобразователя (быстрота), так и продолжить их обучение вместе со слоями классификатора (точность).
#
# ![img](https://drive.google.com/uc?id=1bQubJ7HR9_7jT4RiVBCK4ttkuslO9jB8)
#
#
# Вы решаете какие слои брать для преобразователя, какие для классификатора. Часто бывает так, что достаточно поменять лишь один последний слой.
#
# На любом слое мы получаем некоторые карты признаков, и можем их использовать для классификатора. Мы **перенесли** обученные слои одной сети в другую.
#
# Если нам надо обучить сеть распознавать изображения классов, которые никто не знает и не обучал, то нам нет необходимости делать это с нуля. Возьмем сеть, уже обученную распознавать большое число классов [ILSVRC](http://www.image-net.org/challenges/LSVRC/), и заменим в ней слои классификатора так, чтобы получались наши классы. И будем обучать уже такую составную сеть на новых примерах классов изображений.

# %% [markdown]
# ## Пример
#
# Давайте возьмем обученную сеть для классификации на  1000 классов [VGG16](https://arxiv.org/pdf/1409.1556.pdf) которая [победила в соревновании ImageNet в 2014](http://www.robots.ox.ac.uk/~vgg/research/very_deep/), и используем ее слои для классификации других классов изображений.
#
# Мы загрузим VGG16, удалим последний ее слой (1000 нейронов с softmax) и заменим его на свой (97 нейронов и классов). Мы зафиксируем веса всех слоев, кроме последнего, т.е. не будем их обучать.
#
# Сравним этот подход с попыткой обучить маленькую нейронную сеть с нуля.
#
# В нашем примере мы используем набор данных из 6000 изображений с 97 классами.

# %%
# %matplotlib inline
# подключаем библиотеки
import os
import random
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

from tensorflow.keras.preprocessing import image # преодобработка изображений
from tensorflow.keras.applications.imagenet_utils import preprocess_input # преодобработка изображений для набора данных imagenet
from tensorflow.keras.models import Sequential # последовательное соединение слоев нейронной сети
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation # слои, которые будем использовать
from tensorflow.keras.layers import Conv2D, MaxPooling2D # слои, которые будем использовать
from tensorflow.keras.models import Model # объект нейронной сети в который собираются слои

# %% [markdown]
# ### Загрузка набора данных
#
# Мы используем набор данных [CalTech-101](http://www.vision.caltech.edu/Image_Datasets/Caltech101/), который отличается от ImageNet. Он содержит около 9000 размеченных изображений в 101 классе (в архиве файле есть еще 102ой класс с разными случайными картинками из интернета, но он нам не нужен). Мы исключим 5 классов с наибольшим числом изображений (включая 102ой), чтобы иметь классы с примерно одинаковым числом изображений в каждом (50-100), останется около 6000 изображений в 97 классах. Архив с данными хранится на нашем гугл-диске, чтобы скачать его оттуда используем  библиотеку `gdown`.
#
# Если вы захотите обучать на своих классах, то должны сделать набор данных по аналогии с этим, где каждый класс хранится в поддиректориях, названия которых и определяют название классов. `root` - директория набора данных. Вспомогательная функция  `get_image(path)` загружает изображение и масштабирует его к размеру 224x224, чтобы подходило для VGG16.

# %%
import gdown # модуль для загрузки с гугл-диска
url = 'https://drive.google.com/uc?id=1Madin3qXe3Xexox5qOhASGulFR2wvsFz' # адрес
output = '101_ObjectCategories.tar.gz' # название загружаемого файла
gdown.download(url, output, quiet=False) # загружаем
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Madin3qXe3Xexox5qOhASGulFR2wvsFz
# From (redirected): https://drive.google.com/uc?id=1Madin3qXe3Xexox5qOhASGulFR2wvsFz&confirm=t&uuid=8a81912d-79ae-48e1-b0bc-7ec1cae3551b
# To: /content/101_ObjectCategories.tar.gz
# 100%|██████████| 132M/132M [00:04<00:00, 30.1MB/s]
# '101_ObjectCategories.tar.gz'

# %%
# !echo "Downloading 101_Object_Categories for image notebooks"
# распаковываем
# !tar -xzf 101_ObjectCategories.tar.gz
# удаляем после распаковки
# !rm 101_ObjectCategories.tar.gz
# !ls
# Out:
# Downloading 101_Object_Categories for image notebooks
# 101_ObjectCategories  sample_data

# %%
root = '101_ObjectCategories' # директория с файлами
exclude = ['BACKGROUND_Google', 'Motorbikes', 'airplanes', 'Faces_easy', 'Faces'] # классы, которые исключаем
train_split, val_split = 0.7, 0.15 # доли данных для обучения и проверки

# проходим по всем поддиректориям, они и есть наши классы
categories = [x[0] for x in os.walk(root) if x[0]][1:]
# но исключим некоторые из них
categories = [c for c in categories if c not in [os.path.join(root, e) for e in exclude]]
# посмотрим на классы. Специально оставили в названиях и общее название набора данных, чтобы не перепутать с другими
print(categories)
# Out:
# ['101_ObjectCategories/soccer_ball', '101_ObjectCategories/laptop', '101_ObjectCategories/lamp', '101_ObjectCategories/watch', '101_ObjectCategories/pizza', '101_ObjectCategories/dragonfly', '101_ObjectCategories/kangaroo', '101_ObjectCategories/headphone', '101_ObjectCategories/crocodile_head', '101_ObjectCategories/llama', '101_ObjectCategories/crayfish', '101_ObjectCategories/ketch', '101_ObjectCategories/Leopards', '101_ObjectCategories/barrel', '101_ObjectCategories/gerenuk', '101_ObjectCategories/crab', '101_ObjectCategories/ceiling_fan', '101_ObjectCategories/stapler', '101_ObjectCategories/mandolin', '101_ObjectCategories/garfield', '101_ObjectCategories/ferry', '101_ObjectCategories/stop_sign', '101_ObjectCategories/brain', '101_ObjectCategories/chair', '101_ObjectCategories/pigeon', '101_ObjectCategories/umbrella', '101_ObjectCategories/snoopy', '101_ObjectCategories/rhino', '101_ObjectCategories/euphonium', '101_ObjectCategories/sea_horse', '101_ObjectCategories/cougar_face', '101_ObjectCategories/trilobite', '101_ObjectCategories/stegosaurus', '101_ObjectCategories/bonsai', '101_ObjectCategories/accordion', '101_ObjectCategories/sunflower', '101_ObjectCategories/schooner', '101_ObjectCategories/ant', '101_ObjectCategories/hawksbill', '101_ObjectCategories/dollar_bill', '101_ObjectCategories/windsor_chair', '101_ObjectCategories/saxophone', '101_ObjectCategories/okapi', '101_ObjectCategories/beaver', '101_ObjectCategories/electric_guitar', '101_ObjectCategories/inline_skate', '101_ObjectCategories/gramophone', '101_ObjectCategories/panda', '101_ObjectCategories/grand_piano', '101_ObjectCategories/binocular', '101_ObjectCategories/brontosaurus', '101_ObjectCategories/dalmatian', '101_ObjectCategories/lobster', '101_ObjectCategories/mayfly', '101_ObjectCategories/scissors', '101_ObjectCategories/butterfly', '101_ObjectCategories/revolver', '101_ObjectCategories/wrench', '101_ObjectCategories/flamingo_head', '101_ObjectCategories/ewer', '101_ObjectCategories/minaret', '101_ObjectCategories/water_lilly', '101_ObjectCategories/buddha', '101_ObjectCategories/strawberry', '101_ObjectCategories/cougar_body', '101_ObjectCategories/octopus', '101_ObjectCategories/lotus', '101_ObjectCategories/cannon', '101_ObjectCategories/wheelchair', '101_ObjectCategories/chandelier', '101_ObjectCategories/hedgehog', '101_ObjectCategories/dolphin', '101_ObjectCategories/crocodile', '101_ObjectCategories/elephant', '101_ObjectCategories/yin_yang', '101_ObjectCategories/cup', '101_ObjectCategories/emu', '101_ObjectCategories/joshua_tree', '101_ObjectCategories/cellphone', '101_ObjectCategories/platypus', '101_ObjectCategories/bass', '101_ObjectCategories/menorah', '101_ObjectCategories/wild_cat', '101_ObjectCategories/pagoda', '101_ObjectCategories/anchor', '101_ObjectCategories/nautilus', '101_ObjectCategories/starfish', '101_ObjectCategories/helicopter', '101_ObjectCategories/flamingo', '101_ObjectCategories/rooster', '101_ObjectCategories/car_side', '101_ObjectCategories/camera', '101_ObjectCategories/metronome', '101_ObjectCategories/scorpion', '101_ObjectCategories/ibis', '101_ObjectCategories/pyramid', '101_ObjectCategories/tick']

# %%
# функция для загрузки изображения
def get_image(path):
    img = image.load_img(path, target_size=(224, 224)) # загружаем изображение и масштабируем
    x = image.img_to_array(img) # конвертируем в массив
    x = np.expand_dims(x, axis=0) # добавляем измерение (batch) 1*224*224*3
    x = preprocess_input(x) # предобработка
    return img, x # возвращаем изображение PIL и массив для него

# %% [markdown]
# Загрузка всех изображений.

# %%
data = [] # пустой массив для данных
for c, category in enumerate(categories): # для всех классов, они же поддиректории
    # берем названия всех файлов в ней, объединяем с названием (путем к) самой директории,
    # но только такие, в которых расширение '.jpg','.png','.jpeg'.
    images = [os.path.join(dp, f) for dp, dn, filenames
              in os.walk(category) for f in filenames
              if os.path.splitext(f)[1].lower() in ['.jpg','.png','.jpeg']]
    # для всех изображений класса
    for img_path in images:
        img, x = get_image(img_path) # загружаем его
        data.append({'x':np.array(x[0]), 'y':c}) # добавляем в словарь 'x' - массив изображения и 'y' - номер класса.

# число классов
num_classes = len(categories)

# %%
random.shuffle(data) # перемешаем случайно

# %%
import sys


def sizeof_fmt(num, suffix='B'):
    ''' by Fred Cirera,  https://stackoverflow.com/a/1094933/1870254, modified'''
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f %s%s" % (num, 'Yi', suffix)

# %% [markdown]
# Обучающее, тестовое и проверочное множества (70%, 15%, 15%)

# %%
N=5# часть данных для экономии
idx_val = int(train_split * len(data)/N) # индекс начала для проверочного множества
idx_test = int((train_split + val_split) * len(data)/N) # индекс начала для тестового множества
idx_end=int(int( 1 * len(data)/N))
# разделяем
train = data[:idx_val] #
val = data[idx_val:idx_test] #
test = data[idx_test:idx_end] #

# %%
# разделяем данные и метки в отдельные переменные
x_train, y_train = np.array([t["x"] for t in train]), np.array([t["y"] for t in train])
x_val, y_val = np.array([t["x"] for t in val]), np.array([t["y"] for t in val])
x_test, y_test = np.array([t["x"] for t in test]), np.array([t["y"] for t in test])
#print(y_test)

# %%
# Память
for name, size in sorted(((name, sys.getsizeof(value)) for name, value in locals().items()),
                         key= lambda x: -x[1])[:20]:
    print("{:>30}: {:>8}".format(name, sizeof_fmt(size)))
# Out:
#                        x_train: 499.0 MiB
#                          x_val: 106.8 MiB
#                         x_test: 106.8 MiB
#                           data: 51.8 KiB
#                        y_train:  6.9 KiB
#                          train:  6.8 KiB
#                            _i1:  1.6 KiB
#                          y_val:  1.6 KiB
#                         y_test:  1.6 KiB
#                            _i6:  1.5 KiB
#                            val:  1.5 KiB
#                           test:  1.5 KiB
#                            _i4:  1.3 KiB
#                     Sequential:  1.0 KiB
#                          Dense:  1.0 KiB
#                        Dropout:  1.0 KiB
#                        Flatten:  1.0 KiB
#                     Activation:  1.0 KiB
#                         Conv2D:  1.0 KiB
#                   MaxPooling2D:  1.0 KiB

# %% [markdown]
# Предобработка, перевод в float32 и нормализация к 0...1. Кодирование классов.

# %%
# нормализация
x_train = x_train.astype('float32') / 255.
x_val = x_val.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %%
# НЕНАДО для sparse cross entropy
# конвертируем номера классов в one-hot вектора
#y_train = tf.keras.utils.to_categorical(y_train, num_classes)
#y_val =   tf.keras.utils.to_categorical(y_val, num_classes)
#y_test =  tf.keras.utils.to_categorical(y_test, num_classes)
#print(y_test.shape)

# %%
# ЕСЛИ sparse cross entropy
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

# %% [markdown]
# Что у нас получилось:

# %%
# summary
print("finished loading %d images from %d categories"%(len(data), num_classes))
print("train / validation / test split: %d, %d, %d"%(len(x_train), len(x_val), len(x_test)))
print("training data shape: ", x_train.shape)
print("training labels shape: ", y_train.shape)
# Out:
# finished loading 6209 images from 97 categories
# train / validation / test split: 869, 186, 186
# training data shape:  (869, 224, 224, 3)
# training labels shape:  (869,)

# %% [markdown]
# Если все правильно, то должен получиться набор изображений, разделенный на `train`, `val`, и `test`.
#
# Размер данных входа (`n`, 224, 224, 3) где `n` число примеров.
#
# Указания учителя имеют размер (`n`, `c`) где `c` - число классов (97 в нашем примере `101_ObjectCategories`), если используем кросс-энтропию, и (`n`,), если используем разреженную кросс-энтропию, в последнем случае классы кодируются своим номером.
#
#
# Посмотрим на некоторые изображения.

# %%
# названия всех изображений
images = [os.path.join(dp, f) for dp, dn, filenames in os.walk(root) for f in filenames if os.path.splitext(f)[1].lower() in ['.jpg','.png','.jpeg']]
# выбираем случайно 8 штук
idx = [int(len(images) * random.random()) for i in range(8)]
# загружаем эти изображения
imgs = [image.load_img(images[i], target_size=(224, 224)) for i in idx]
# объединяем в одну строку
concat_image = np.concatenate([np.asarray(img) for img in imgs], axis=1)
# рисуем
plt.figure(figsize=(16,4))
plt.imshow(concat_image)

# %% [markdown]
# # Обучение нейронной сети с нуля
#
# Эта нейронная сеть будет состоять из 4 сверточных слоев и max-pooling, со слоем [dropout](https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf) после каждых двух слоев свертки\пулинга. Затем подключаем полносвязный слой с 128 нейронами, еще слой dropout, и, наконец, полносвязный слой с softmax для классификации (а сколько в нем нейронов?).
#
# Функцию ошибки возьмем кросс-энтропию, метод обучения Adam.
#
# Вы можете поменять параметры.

# %%
# создаем нейронную сеть
channels=16
model = Sequential() # последовательное подключение слоев
print("Input dimensions: ",x_train.shape[1:]) # размер входа

model.add(Conv2D(channels, (3, 3), input_shape=x_train.shape[1:])) #  свертка
model.add(Activation('relu')) # активация
model.add(MaxPooling2D(pool_size=(2, 2))) # пулинг

model.add(Conv2D(channels, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25)) # dropout

model.add(Conv2D(channels, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(channels, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25))

model.add(Flatten()) # вытягиваем результаты сверток в вектор
model.add(Dense(128))# полносвязный слой
model.add(Activation('relu'))

model.add(Dropout(0.5))

model.add(Dense(num_classes)) # полносвязный слой классификации
model.add(Activation('softmax')) # активация softmax

model.summary() # напечатаем информацию о сети
# Out:
# Input dimensions:  (224, 224, 3)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 222, 222, 16)      448
#
#  activation_6 (Activation)   (None, 222, 222, 16)      0
#
#  max_pooling2d_4 (MaxPoolin  (None, 111, 111, 16)      0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 109, 109, 16)      2320
#
#  activation_7 (Activation)   (None, 109, 109, 16)      0
#
#  max_pooling2d_5 (MaxPoolin  (None, 54, 54, 16)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 54, 54, 16)        0
#
#  conv2d_6 (Conv2D)           (None, 52, 52, 16)        2320
#
#  activation_8 (Activation)   (None, 52, 52, 16)        0
#
#  max_pooling2d_6 (MaxPoolin  (None, 26, 26, 16)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 16)        2320
#
#  activation_9 (Activation)   (None, 24, 24, 16)        0
#
#  max_pooling2d_7 (MaxPoolin  (None, 12, 12, 16)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 12, 12, 16)        0
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_3 (Dense)             (None, 128)               295040
#
#  activation_10 (Activation)  (None, 128)               0
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 97)                12513
#
#  activation_11 (Activation)  (None, 97)                0
#
# =================================================================
# Total params: 314961 (1.20 MB)
# Trainable params: 314961 (1.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Мы получили сеть в которой ~0.3 млн. весов и смещений, большинство из них в первом полносвязном слое.
#
# Будем обучать нашу модель 20  эпох (поменяйте) с пакетом размера 64. Будем записывать историю.

# %%
# компилируем модель и указываем опции обучения
model.compile(loss='SparseCategoricalCrossentropy', #  функция ошибки
              optimizer='adam', # метод обучения
              metrics=['accuracy']) #  измеряемые метрики

# %%
# обучаем модель
history = model.fit(x_train, # примеры входа
                    y_train, # указания учителя
                    batch_size=32, # размер пакета
                    epochs=100, # количество эпох
                    validation_data=(x_val, y_val)) #  данные для проверки
# Out:
# Epoch 1/100
# 28/28 [==============================] - 3s 54ms/step - loss: 4.5784 - accuracy: 0.0242 - val_loss: 4.5689 - val_accuracy: 0.0430
# Epoch 2/100
# 28/28 [==============================] - 1s 40ms/step - loss: 4.5327 - accuracy: 0.0357 - val_loss: 4.5599 - val_accuracy: 0.0430
# Epoch 3/100
# 28/28 [==============================] - 1s 38ms/step - loss: 4.4814 - accuracy: 0.0391 - val_loss: 4.5360 - val_accuracy: 0.0430
# Epoch 4/100
# 28/28 [==============================] - 1s 38ms/step - loss: 4.4270 - accuracy: 0.0495 - val_loss: 4.5174 - val_accuracy: 0.0806
# Epoch 5/100
# 28/28 [==============================] - 1s 40ms/step - loss: 4.3252 - accuracy: 0.0667 - val_loss: 4.4466 - val_accuracy: 0.0968
# Epoch 6/100
# 28/28 [==============================] - 1s 40ms/step - loss: 4.1803 - accuracy: 0.1036 - val_loss: 4.4209 - val_accuracy: 0.1022
# Epoch 7/100
# 28/28 [==============================] - 1s 42ms/step - loss: 3.9985 - accuracy: 0.1151 - val_loss: 4.3546 - val_accuracy: 0.0860
# Epoch 8/100
# 28/28 [==============================] - 1s 44ms/step - loss: 3.7901 - accuracy: 0.1461 - val_loss: 4.2545 - val_accuracy: 0.1129
# Epoch 9/100
# 28/28 [==============================] - 1s 41ms/step - loss: 3.5737 - accuracy: 0.1910 - val_loss: 4.1685 - val_accuracy: 0.1398
# Epoch 10/100
# 28/28 [==============================] - 1s 41ms/step - loss: 3.3180 - accuracy: 0.2359 - val_loss: 4.1065 - val_accuracy: 0.1505
# Epoch 11/100
# 28/28 [==============================] - 1s 38ms/step - loss: 2.9462 - accuracy: 0.2969 - val_loss: 4.1390 - val_accuracy: 0.1720
# Epoch 12/100
# 28/28 [==============================] - 1s 39ms/step - loss: 2.8340 - accuracy: 0.3049 - val_loss: 3.9962 - val_accuracy: 0.1774
# Epoch 13/100
# 28/28 [==============================] - 1s 41ms/step - loss: 2.4300 - accuracy: 0.3843 - val_loss: 3.9673 - val_accuracy: 0.2151
# Epoch 14/100
# 28/28 [==============================] - 1s 38ms/step - loss: 2.1471 - accuracy: 0.4465 - val_loss: 4.1278 - val_accuracy: 0.1989
# Epoch 15/100
# 28/28 [==============================] - 1s 38ms/step - loss: 1.9560 - accuracy: 0.4948 - val_loss: 4.0322 - val_accuracy: 0.1989
# Epoch 16/100
# 28/28 [==============================] - 1s 39ms/step - loss: 1.8035 - accuracy: 0.5190 - val_loss: 4.1991 - val_accuracy: 0.2151
# Epoch 17/100
# 28/28 [==============================] - 1s 38ms/step - loss: 1.6765 - accuracy: 0.5673 - val_loss: 4.1844 - val_accuracy: 0.2312
# Epoch 18/100
# 28/28 [==============================] - 1s 42ms/step - loss: 1.5081 - accuracy: 0.5926 - val_loss: 4.1682 - val_accuracy: 0.2312
# Epoch 19/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.3897 - accuracy: 0.6249 - val_loss: 4.4227 - val_accuracy: 0.2312
# Epoch 20/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.3236 - accuracy: 0.6260 - val_loss: 4.3737 - val_accuracy: 0.2097
# Epoch 21/100
# 28/28 [==============================] - 1s 38ms/step - loss: 1.2123 - accuracy: 0.6467 - val_loss: 4.4449 - val_accuracy: 0.2097
# Epoch 22/100
# 28/28 [==============================] - 1s 38ms/step - loss: 1.0077 - accuracy: 0.7135 - val_loss: 4.5660 - val_accuracy: 0.1828
# Epoch 23/100
# 28/28 [==============================] - 1s 42ms/step - loss: 0.9563 - accuracy: 0.7273 - val_loss: 4.7369 - val_accuracy: 0.2204
# Epoch 24/100
# 28/28 [==============================] - 1s 51ms/step - loss: 0.9380 - accuracy: 0.7411 - val_loss: 4.5898 - val_accuracy: 0.2312
# Epoch 25/100
# 28/28 [==============================] - 1s 51ms/step - loss: 0.8089 - accuracy: 0.7503 - val_loss: 4.6115 - val_accuracy: 0.1935
# Epoch 26/100
# 28/28 [==============================] - 1s 42ms/step - loss: 0.7960 - accuracy: 0.7814 - val_loss: 4.7922 - val_accuracy: 0.2527
# Epoch 27/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.7433 - accuracy: 0.7756 - val_loss: 5.0390 - val_accuracy: 0.2151
# Epoch 28/100
# 28/28 [==============================] - 1s 41ms/step - loss: 0.7434 - accuracy: 0.7756 - val_loss: 4.8009 - val_accuracy: 0.2366
# Epoch 29/100
# 28/28 [==============================] - 1s 46ms/step - loss: 0.6634 - accuracy: 0.8113 - val_loss: 5.0624 - val_accuracy: 0.2581
# Epoch 30/100
# 28/28 [==============================] - 1s 44ms/step - loss: 0.6050 - accuracy: 0.8205 - val_loss: 5.2832 - val_accuracy: 0.2366
# Epoch 31/100
# 28/28 [==============================] - 1s 39ms/step - loss: 0.6001 - accuracy: 0.8170 - val_loss: 5.1471 - val_accuracy: 0.2151
# Epoch 32/100
# 28/28 [==============================] - 1s 39ms/step - loss: 0.6774 - accuracy: 0.8021 - val_loss: 5.0110 - val_accuracy: 0.2366
# Epoch 33/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.6076 - accuracy: 0.8205 - val_loss: 5.1549 - val_accuracy: 0.2204
# Epoch 34/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.5240 - accuracy: 0.8562 - val_loss: 5.4797 - val_accuracy: 0.2473
# Epoch 35/100
# 28/28 [==============================] - 1s 40ms/step - loss: 0.5581 - accuracy: 0.8297 - val_loss: 5.6374 - val_accuracy: 0.2312
# Epoch 36/100
# 28/28 [==============================] - 1s 39ms/step - loss: 0.4469 - accuracy: 0.8573 - val_loss: 5.7297 - val_accuracy: 0.2043
# Epoch 37/100
# 28/28 [==============================] - 1s 41ms/step - loss: 0.4910 - accuracy: 0.8573 - val_loss: 5.5735 - val_accuracy: 0.2258
# Epoch 38/100
# 28/28 [==============================] - 1s 39ms/step - loss: 0.4480 - accuracy: 0.8757 - val_loss: 5.5370 - val_accuracy: 0.2366
# Epoch 39/100
# 28/28 [==============================] - 1s 41ms/step - loss: 0.5008 - accuracy: 0.8550 - val_loss: 5.8478 - val_accuracy: 0.2258
# Epoch 40/100
# 28/28 [==============================] - 1s 45ms/step - loss: 0.4075 - accuracy: 0.8677 - val_loss: 5.6211 - val_accuracy: 0.2312
# Epoch 41/100
# 28/28 [==============================] - 1s 42ms/step - loss: 0.4482 - accuracy: 0.8573 - val_loss: 5.8070 - val_accuracy: 0.2258
# Epoch 42/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.4210 - accuracy: 0.8757 - val_loss: 5.2792 - val_accuracy: 0.2097
# Epoch 43/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.4357 - accuracy: 0.8723 - val_loss: 5.7787 - val_accuracy: 0.2097
# Epoch 44/100
# 28/28 [==============================] - 1s 41ms/step - loss: 0.4138 - accuracy: 0.8677 - val_loss: 6.0625 - val_accuracy: 0.2258
# Epoch 45/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.4483 - accuracy: 0.8642 - val_loss: 5.6829 - val_accuracy: 0.2366
# Epoch 46/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.3799 - accuracy: 0.8838 - val_loss: 5.9642 - val_accuracy: 0.2419
# Epoch 47/100
# 28/28 [==============================] - 1s 40ms/step - loss: 0.3547 - accuracy: 0.8953 - val_loss: 5.7233 - val_accuracy: 0.2204
# Epoch 48/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.3620 - accuracy: 0.8826 - val_loss: 5.7898 - val_accuracy: 0.2312
# Epoch 49/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.3461 - accuracy: 0.8895 - val_loss: 5.9782 - val_accuracy: 0.2151
# Epoch 50/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.3800 - accuracy: 0.8941 - val_loss: 6.4526 - val_accuracy: 0.2043
# Epoch 51/100
# 28/28 [==============================] - 1s 46ms/step - loss: 0.3886 - accuracy: 0.8815 - val_loss: 6.3531 - val_accuracy: 0.2312
# Epoch 52/100
# 28/28 [==============================] - 1s 46ms/step - loss: 0.3457 - accuracy: 0.8907 - val_loss: 6.1058 - val_accuracy: 0.2043
# Epoch 53/100
# 28/28 [==============================] - 1s 39ms/step - loss: 0.3570 - accuracy: 0.8895 - val_loss: 6.1243 - val_accuracy: 0.2151
# Epoch 54/100
# 28/28 [==============================] - 1s 40ms/step - loss: 0.3037 - accuracy: 0.8918 - val_loss: 6.0773 - val_accuracy: 0.2312
# Epoch 55/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.3623 - accuracy: 0.8849 - val_loss: 6.0695 - val_accuracy: 0.2204
# Epoch 56/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.4162 - accuracy: 0.8769 - val_loss: 5.9821 - val_accuracy: 0.2043
# Epoch 57/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2985 - accuracy: 0.8953 - val_loss: 6.1236 - val_accuracy: 0.2419
# Epoch 58/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.3130 - accuracy: 0.8976 - val_loss: 6.1323 - val_accuracy: 0.2204
# Epoch 59/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.3561 - accuracy: 0.8987 - val_loss: 6.2646 - val_accuracy: 0.1720
# Epoch 60/100
# 28/28 [==============================] - 1s 39ms/step - loss: 0.2947 - accuracy: 0.9125 - val_loss: 6.2429 - val_accuracy: 0.2312
# Epoch 61/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2837 - accuracy: 0.9114 - val_loss: 6.2881 - val_accuracy: 0.2151
# Epoch 62/100
# 28/28 [==============================] - 1s 45ms/step - loss: 0.2772 - accuracy: 0.9079 - val_loss: 6.2389 - val_accuracy: 0.2258
# Epoch 63/100
# 28/28 [==============================] - 1s 45ms/step - loss: 0.2751 - accuracy: 0.9125 - val_loss: 6.3541 - val_accuracy: 0.2258
# Epoch 64/100
# 28/28 [==============================] - 1s 41ms/step - loss: 0.3467 - accuracy: 0.8976 - val_loss: 6.0456 - val_accuracy: 0.2312
# Epoch 65/100
# 28/28 [==============================] - 1s 40ms/step - loss: 0.2742 - accuracy: 0.9125 - val_loss: 6.1788 - val_accuracy: 0.2312
# Epoch 66/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.3193 - accuracy: 0.9022 - val_loss: 6.2546 - val_accuracy: 0.2312
# Epoch 67/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2822 - accuracy: 0.9148 - val_loss: 6.4168 - val_accuracy: 0.2204
# Epoch 68/100
# 28/28 [==============================] - 1s 41ms/step - loss: 0.2358 - accuracy: 0.9333 - val_loss: 7.0500 - val_accuracy: 0.2151
# Epoch 69/100
# 28/28 [==============================] - 1s 40ms/step - loss: 0.2650 - accuracy: 0.9287 - val_loss: 7.0768 - val_accuracy: 0.2151
# Epoch 70/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2875 - accuracy: 0.9114 - val_loss: 6.8727 - val_accuracy: 0.2258
# Epoch 71/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2538 - accuracy: 0.9229 - val_loss: 6.2957 - val_accuracy: 0.2312
# Epoch 72/100
# 28/28 [==============================] - 1s 40ms/step - loss: 0.2409 - accuracy: 0.9287 - val_loss: 6.6985 - val_accuracy: 0.2043
# Epoch 73/100
# 28/28 [==============================] - 1s 45ms/step - loss: 0.3039 - accuracy: 0.9045 - val_loss: 7.2407 - val_accuracy: 0.1828
# Epoch 74/100
# 28/28 [==============================] - 1s 46ms/step - loss: 0.2215 - accuracy: 0.9298 - val_loss: 7.0208 - val_accuracy: 0.2043
# Epoch 75/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2678 - accuracy: 0.9114 - val_loss: 6.8383 - val_accuracy: 0.1989
# Epoch 76/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2223 - accuracy: 0.9379 - val_loss: 6.7691 - val_accuracy: 0.2043
# Epoch 77/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2584 - accuracy: 0.9217 - val_loss: 6.7780 - val_accuracy: 0.2258
# Epoch 78/100
# 28/28 [==============================] - 1s 40ms/step - loss: 0.2778 - accuracy: 0.9148 - val_loss: 6.7316 - val_accuracy: 0.1989
# Epoch 79/100
# 28/28 [==============================] - 1s 39ms/step - loss: 0.2381 - accuracy: 0.9264 - val_loss: 6.2752 - val_accuracy: 0.2151
# Epoch 80/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2215 - accuracy: 0.9275 - val_loss: 6.9174 - val_accuracy: 0.2097
# Epoch 81/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2184 - accuracy: 0.9252 - val_loss: 6.6584 - val_accuracy: 0.2097
# Epoch 82/100
# 28/28 [==============================] - 1s 40ms/step - loss: 0.2118 - accuracy: 0.9298 - val_loss: 6.9291 - val_accuracy: 0.2366
# Epoch 83/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2068 - accuracy: 0.9379 - val_loss: 6.9631 - val_accuracy: 0.2366
# Epoch 84/100
# 28/28 [==============================] - 1s 45ms/step - loss: 0.1967 - accuracy: 0.9367 - val_loss: 7.0666 - val_accuracy: 0.2366
# Epoch 85/100
# 28/28 [==============================] - 1s 44ms/step - loss: 0.2498 - accuracy: 0.9183 - val_loss: 6.6973 - val_accuracy: 0.2151
# Epoch 86/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.2484 - accuracy: 0.9183 - val_loss: 6.7258 - val_accuracy: 0.2312
# Epoch 87/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2356 - accuracy: 0.9344 - val_loss: 6.4564 - val_accuracy: 0.1882
# Epoch 88/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.2420 - accuracy: 0.9241 - val_loss: 6.6043 - val_accuracy: 0.2258
# Epoch 89/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2408 - accuracy: 0.9252 - val_loss: 6.4514 - val_accuracy: 0.1989
# Epoch 90/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.1854 - accuracy: 0.9367 - val_loss: 7.1898 - val_accuracy: 0.2473
# Epoch 91/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2183 - accuracy: 0.9333 - val_loss: 6.7326 - val_accuracy: 0.2204
# Epoch 92/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2668 - accuracy: 0.9194 - val_loss: 6.5225 - val_accuracy: 0.2258
# Epoch 93/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2597 - accuracy: 0.9229 - val_loss: 6.7313 - val_accuracy: 0.2097
# Epoch 94/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2170 - accuracy: 0.9344 - val_loss: 6.9250 - val_accuracy: 0.2419
# Epoch 95/100
# 28/28 [==============================] - 1s 43ms/step - loss: 0.1917 - accuracy: 0.9367 - val_loss: 6.8451 - val_accuracy: 0.2204
# Epoch 96/100
# 28/28 [==============================] - 1s 45ms/step - loss: 0.2189 - accuracy: 0.9287 - val_loss: 7.0725 - val_accuracy: 0.2204
# Epoch 97/100
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1312 - accuracy: 0.9586 - val_loss: 6.9818 - val_accuracy: 0.2097
# Epoch 98/100
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1450 - accuracy: 0.9574 - val_loss: 7.1823 - val_accuracy: 0.2097
# Epoch 99/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.1824 - accuracy: 0.9379 - val_loss: 7.6768 - val_accuracy: 0.2312
# Epoch 100/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2254 - accuracy: 0.9217 - val_loss: 7.2489 - val_accuracy: 0.1935

# %% [markdown]
# Построим графики для функции ошибки и метрики аккуратности на проверочных данных.

# %%
fig = plt.figure(figsize=(16,4))
ax = fig.add_subplot(121)
ax.plot(history.history["val_loss"]) # функция ошибки
ax.set_title("validation loss")
ax.set_xlabel("epochs")

ax2 = fig.add_subplot(122)
ax2.plot(history.history["val_accuracy"]) # метрика аккуратности
ax2.set_title("validation accuracy")
ax2.set_xlabel("epochs")
ax2.set_ylim(0, 1)

plt.show()

# %% [markdown]
# Получили что-то около 20% аккуратности. Вряд ли за малое время обучения она возрастет существенно, попытайтесь.
#
# Проверим на тестовых данных.

# %%
# Память
for name, size in sorted(((name, sys.getsizeof(value)) for name, value in locals().items()),
                         key= lambda x: -x[1])[:20]:
    print("{:>30}: {:>8}".format(name, sizeof_fmt(size)))
# Out:
#                        x_train: 499.0 MiB
#                          x_val: 106.8 MiB
#                         x_test: 106.8 MiB
#                   concat_image:  1.1 MiB
#                         images: 73.9 KiB
#                           data: 51.8 KiB
#                        y_train:  6.9 KiB
#                          train:  6.8 KiB
#                           _i17:  2.1 KiB
#                            _i1:  1.6 KiB
#                          y_val:  1.6 KiB
#                         y_test:  1.6 KiB
#                            _i6:  1.5 KiB
#                            val:  1.5 KiB
#                           test:  1.5 KiB
#                            _i4:  1.3 KiB
#                           _i16:  1.1 KiB
#                          Model:  1.0 KiB
#                     categories:  920.0 B
#                     Sequential:  904.0 B

# %%
# del history

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=0) # проверяем на тестовых данных
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Test loss: 9.051408767700195
# Test accuracy: 0.1666666716337204

# %% [markdown]
# Итак, аккуратность около 20%. Не так плохо, но и не так хорошо. Для 97 классов, если бы мы случайно угадывали бы класс, получили бы что-то около 1% аккуратности.
#
# # Используем предобученную сеть
#
# Теперь сделаем тоже самое, но будем использовать уже обученную сеть, а заменим только слои для классификации.

# %%
# скачиваем обученную сеть
from tensorflow.keras import applications
vgg = applications.VGG16(weights='imagenet', include_top=True)
vgg.summary() # ее описание
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 25s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138357544 (527.79 MB)
# Trainable params: 138357544 (527.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Эта сеть, VGG16, _гораздо_ больше нашей. Содержит 13 сверточных слоев, два полносвязных и более 138 миллионов обучаемых параметров, что почти в 250 раз больше чем было у нас.
#
# VGG16 обучалась на ImageNet и показала [8.8% top-5 ошибку](https://github.com/jcjohnson/cnn-benchmarks), это значит что 91.2% тестовых примеров были классифицированы правильно и верные классы входили в top 5 самых уверенных. top-1 аккуратность около 73%. И при этом в ней не 97, а 1000 классов (случайное угадывание дало бы 0.1% аккуратности).
#
# Чтобы использовать такую сеть мы "отрежем" последний слой с 1000 нейронами (которые отвечают за 1000 классов ImageNet) и заменим его на слой с 97 нейронами для нашего набора данных.
#
# Технически мы не будем ничего отрезать, а сделаем копию слоев VGG до предпоследнего. Используем класс `Model` чтобы создать сеть, объединяя вход VGG, и слои VGG до предпоследнего с новым слоем, названного `new_classification_layer`. Мы возьмем выход предпоследнего слоя VGG и подадим его на новый слой. Не беспокойтесь что при копировании мы тратим память, Keras просто ссылается на нужные места и фактически ничего не копируется.

# %%
# ссылка на вход VGG
inp = vgg.input

# новый полносвязный слой классификации с softmax и num_classes нейронов
new_classification_layer = Dense(num_classes, activation='softmax')

# подключаем новый слой к выходу предпоследнего слоя VGG (индекс -2), и делаем ссылку на него
out = new_classification_layer(vgg.layers[-2].output)

# создаем сеть от входа до нового выхода.
model_new = Model(inp, out)

# %% [markdown]
# Мы будем обучать эту сеть `model_new` на новых изображениях и классах, но мы заморозим (зафиксируем) веса и смещения у всех слоев, кроме нового последнего и будем обучать только последний слой. Устанавливаем флаг `trainable` в false. Если время и ресурсы позволяют, можете обучать и всю сеть целиком.
#
# В качестве упражнения разрешите обучать также веса предпоследнего слоя.

# %%
# запрещаем обучение всех весов\смещений для слоев кроме последнего
for l, layer in enumerate(model_new.layers[:-1]):
    layer.trainable = False

# на всякий случай последнему слою разрешаем обучаться
for l, layer in enumerate(model_new.layers[-1:]):
    layer.trainable = True

# компилируем модель и указываем опции обучения
model_new.compile(loss='SparseCategoricalCrossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model_new.summary() # печатаем информацию о модели
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 97)                397409
#
# =================================================================
# Total params: 134657953 (513.68 MB)
# Trainable params: 397409 (1.52 MB)
# Non-trainable params: 134260544 (512.16 MB)
# _________________________________________________________________

# %% [markdown]
# Получили сеть похожую на исходную VGG, кроме последнего слоя, имеем 134 миллиона параметров, но обучаемых среди них только 397 тысяч, почти столько же, как в нашей собственной сети.
#
# Обучаем.

# %%
# обучаем
history2 = model_new.fit(x_train, y_train,
                         batch_size=32,
                         epochs=20,
                         validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 28/28 [==============================] - 20s 460ms/step - loss: 5.5214 - accuracy: 0.0644 - val_loss: 4.7404 - val_accuracy: 0.1183
# Epoch 2/20
# 28/28 [==============================] - 5s 179ms/step - loss: 3.6549 - accuracy: 0.2589 - val_loss: 3.7397 - val_accuracy: 0.2634
# Epoch 3/20
# 28/28 [==============================] - 5s 181ms/step - loss: 2.9882 - accuracy: 0.3521 - val_loss: 3.4060 - val_accuracy: 0.2634
# Epoch 4/20
# 28/28 [==============================] - 5s 164ms/step - loss: 2.3522 - accuracy: 0.4776 - val_loss: 3.0298 - val_accuracy: 0.3226
# Epoch 5/20
# 28/28 [==============================] - 5s 182ms/step - loss: 1.9995 - accuracy: 0.5466 - val_loss: 2.6803 - val_accuracy: 0.3925
# Epoch 6/20
# 28/28 [==============================] - 5s 166ms/step - loss: 1.7526 - accuracy: 0.6018 - val_loss: 3.0136 - val_accuracy: 0.3441
# Epoch 7/20
# 28/28 [==============================] - 5s 184ms/step - loss: 1.5166 - accuracy: 0.6467 - val_loss: 2.4965 - val_accuracy: 0.4140
# Epoch 8/20
# 28/28 [==============================] - 5s 185ms/step - loss: 1.3558 - accuracy: 0.6928 - val_loss: 2.1655 - val_accuracy: 0.4946
# Epoch 9/20
# 28/28 [==============================] - 5s 183ms/step - loss: 1.1590 - accuracy: 0.7388 - val_loss: 2.3667 - val_accuracy: 0.4570
# Epoch 10/20
# 28/28 [==============================] - 5s 165ms/step - loss: 1.0603 - accuracy: 0.7629 - val_loss: 2.1109 - val_accuracy: 0.5000
# Epoch 11/20
# 28/28 [==============================] - 5s 180ms/step - loss: 0.9947 - accuracy: 0.7618 - val_loss: 2.0319 - val_accuracy: 0.5430
# Epoch 12/20
# 28/28 [==============================] - 5s 162ms/step - loss: 0.9898 - accuracy: 0.7629 - val_loss: 2.0410 - val_accuracy: 0.5376
# Epoch 13/20
# 28/28 [==============================] - 5s 180ms/step - loss: 0.7893 - accuracy: 0.8159 - val_loss: 2.1312 - val_accuracy: 0.4946
# Epoch 14/20
# 28/28 [==============================] - 5s 179ms/step - loss: 0.7616 - accuracy: 0.8262 - val_loss: 2.1334 - val_accuracy: 0.5108
# Epoch 15/20
# 28/28 [==============================] - 4s 161ms/step - loss: 0.7467 - accuracy: 0.8124 - val_loss: 2.0036 - val_accuracy: 0.5538
# Epoch 16/20
# 28/28 [==============================] - 4s 161ms/step - loss: 0.6228 - accuracy: 0.8861 - val_loss: 1.9373 - val_accuracy: 0.5914
# Epoch 17/20
# 28/28 [==============================] - 5s 179ms/step - loss: 0.5718 - accuracy: 0.8849 - val_loss: 2.1235 - val_accuracy: 0.5054
# Epoch 18/20
# 28/28 [==============================] - 4s 161ms/step - loss: 0.5263 - accuracy: 0.8872 - val_loss: 1.9848 - val_accuracy: 0.5699
# Epoch 19/20
# 28/28 [==============================] - 5s 178ms/step - loss: 0.4716 - accuracy: 0.9102 - val_loss: 1.8543 - val_accuracy: 0.5538
# Epoch 20/20
# 28/28 [==============================] - 4s 161ms/step - loss: 0.4407 - accuracy: 0.9068 - val_loss: 1.7089 - val_accuracy: 0.5806

# %% [markdown]
# Аккуратность около 50%, что  на 30% больше, чем ранее. Проверьте, а быстрей ли эта сеть или нет?
# Одна эпоха старой сети длилась примерно 1 сек., в новой сети около 5 сек. Но новая сеть имеет в 250 раз больше параметров, большая часть из которых уже обучена заранее, нам не надо тратить свое время на них. Обучается в новой сети примерно такое же количество параметров, но качество гораздо лучше.
#
# Построим графики (оранжевая - новая сеть).

# %%
fig = plt.figure(figsize=(16,4))
ax = fig.add_subplot(121)
ax.plot(history.history["val_loss"]) # функция ошибки предыдущей сети
ax.plot(history2.history["val_loss"]) # функция ошибки этой сети
ax.set_title("validation loss")
ax.set_xlabel("epochs")

ax2 = fig.add_subplot(122)
ax2.plot(history.history["val_accuracy"]) # аккуратность предыдущей сети
ax2.plot(history2.history["val_accuracy"]) # аккуратность этой сети
ax2.set_title("validation accuracy")
ax2.set_xlabel("epochs")
ax2.set_ylim(0, 1)

plt.show()

# %% [markdown]
# Проверим на тестовых данных.

# %%
loss, accuracy = model_new.evaluate(x_test, y_test, verbose=0)

print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Test loss: 1.9861056804656982
# Test accuracy: 0.5483871102333069

# %% [markdown]
# Для работы с новыми изображениями рассчитайте уровни уверенности классов, выберите максимальный.

# %%
img, x = get_image('101_ObjectCategories/airplanes/image_0007.jpg')
probabilities = model_new.predict([x])
id=np.argmax(probabilities)
print(categories[id],probabilities[0,id])
img
# Out:
# 1/1 [==============================] - 1s 1s/step
# 101_ObjectCategories/helicopter 0.9972614
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# Вопрос, а почему в примере выше вы никогда не получите правильный класс airplanes?

# %% [markdown]
# Почему это работает?
# Изображения схожи между собой. Взаимосвязи пикселей, а именно они устанавливаются при обучении, похожи, неважно различаете вы котика от собачек или слоников от бегемотиков. Или как говорят - схожие домены.
#
# _лапка-лапка, хвостик-хвостик, глазик-глазик_
# ![img](https://media.gettyimages.com/vectors/animals-elephant-cat-zebra-giraffe-rhino-lion-gazelle-vector-id165079601?s=2048x2048)
#
# Наверное, если природа изображений существенно отличается, то перенос обучения не поможет. Например, захотите различать шумы аналогового телевизора и фотографию гравия. Вряд ли здесь поможет сеть, обученная на распознавание бытовых картинок.
#
# ![img](https://media.istockphoto.com/photos/static-background-picture-id124532805)
# ![img](https://media.istockphoto.com/photos/wash-gravel-floors-on-the-outside-of-the-building-picture-id1184617226)

# %% [markdown]
# # Ссылки
# Использованы и адаптированы материалы:
#
# https://colab.research.google.com/github/kylemath/ml4a-guides/blob/master/notebooks/transfer-learning.ipynb
